# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
from IPython.display import display
import re
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.linear_model import LinearRegression, Lasso, LassoCV, Ridge, RidgeCV
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# Importacion del dataset de PRoperaty pre-Procesado anteriormente

# %%
dfprop=pd.read_csv(filepath_or_buffer='properati_buffered.csv',delimiter=',',index_col = 0 )

# %% [markdown]
# Se elimina las columnas 'cota_inf' y 'cota_sup'.
# Adicionalmente se genera una columna unificando la ubicacion

# %%
dfprop.drop(['cota_inf','cota_sup'],axis=1,inplace=True)

# %%
# Generamos una key de zona
dfprop['district_name_key']=dfprop['country_name']+"-"+\
                            dfprop['state_name']+"-"+\
                            dfprop['district_name']

# %% [markdown]
# ## Construccion de Dummies
# -  Efectuar una inspeccion de los campos title y description para indicar la existencia de palabras claves

# %%
def new_dummy_from_included_in_column(dfprop_aux,column,word):
    #dfprop_aux=dfprop
    #word='POZO'
    
    #Creamos la expresion regular ..."que el texto empiece con"... word 
    re_word="("+word+")"
    
    #Creamos la expresion regular
    re_search=dfprop[column].str.extract(re_word,expand=False)
    
    #re_search[((re_search!=-1)&(~(pd.isna(re_search))))].index
    #Creamos la columna dummy y seteamos todos los rows en 0
    dfprop_aux.loc[:,"dm_"+word]=0
    
    #Extraemos la lista de de indices donde la expresion se cumple
    prop_re_list =np.array(re_search[((re_search!=-1)&(~(pd.isna(re_search))))].index)
    
    #Actualizamos el valor de la columna Dummy a 1 en los casos dentro del indice enviado
    dfprop_aux.loc[dfprop_aux.index.isin(prop_re_list),"dm_"+word]=1
    
    print_dummy_count_rows(dfprop_aux,"dm_"+word)
    
    return dfprop_aux


def print_dummy_count_rows(dfprop_aux_p,word_p):
    print('Cantidad de rows con '+word_p+": ",dfprop_aux_p.loc[dfprop_aux_p[word_p]==1,'operation'].count())

# %%
def generate_dummies_per_location(dfprop_aux):
    total_district_name_key=len(dfprop_aux['district_name_key'].unique())
    i=1
    for district_name_key in dfprop_aux['district_name_key'].unique():
        #print(str(i)+" de "+str(total_district_name_key)+" - Generando Dummy para localidad: "+district_name_key)
        dfprop_aux=new_dummy_from_included_in_column(dfprop_aux,'district_name_key',district_name_key)
        i+=1
    return dfprop_aux

# %%
def plot_price_dispersion(dfprop_plot):
    sns.set_style('ticks')
    fig, ax = plt.subplots()
    # the size of A4 paper
    fig.set_size_inches(11.7, 8.27)
    sns.catplot(y="district_name_key", x="price_usd_per_m2", data=dfprop_plot,ax=ax);

# %%
def clean_outliers(dfprop_outlier):
    # Agrupamos por key y sacamos precio promedio
    dfprop_quartile=dfprop_outlier.groupby(by = ['district_name_key'])["price_usd_per_m2"].describe()
    dfprop_quartile['district_name_key']=dfprop_quartile.index
    dfprop_group_quartiles=dfprop_quartile[['25%','75%','district_name_key']]
    dfprop_group_quartiles['cota_inf']=dfprop_group_quartiles['25%']-((dfprop_group_quartiles['75%']-dfprop_group_quartiles['25%'])*1.5)
    dfprop_group_quartiles['cota_sup']=dfprop_group_quartiles['75%']+((dfprop_group_quartiles['75%']-dfprop_group_quartiles['25%'])*1.5)
    dfprop_group_quartiles=dfprop_group_quartiles[['cota_inf','cota_sup']]
    dfprop_group_quartiles
    dfprop_outlier=pd.merge(dfprop_outlier,dfprop_group_quartiles,how='left',on='district_name_key')
    dfprop_outlier=dfprop_outlier.loc[(dfprop_outlier['price_usd_per_m2']>dfprop_outlier['cota_inf'])&(dfprop_outlier['price_usd_per_m2']<dfprop_outlier['cota_sup'])]
    
    #Eliminamos las cotas
    dfprop_outlier.drop(['cota_inf','cota_sup'],axis=1,inplace=True)
    
    return dfprop_outlier

# %%
a=dfprop.columns
for i in a:
    print("'"+i+"',")
# Out:
# 'operation',
# 'property_type',
# 'place_name',
# 'place_with_parent_names',
# 'country_name',
# 'state_name',
# 'geonames_id',
# 'lat-lon',
# 'lat',
# 'lon',
# 'price',
# 'currency',
# 'price_aprox_local_currency',
# 'price_aprox_usd',
# 'surface_total_in_m2',
# 'surface_covered_in_m2',
# 'price_usd_per_m2',
# 'price_per_m2',
# 'floor',
# 'rooms',
# 'expenses',
# 'properati_url',
# 'description',
# 'title',
# 'image_thumbnail',
# 'district_name',
# 'city_name',
# 'district_name_key',

# %%
def getFeaturers(dfprop_in):
    column_features=[
        #'surface_total_in_m2',
    'dm_house',
    'dm_apartment',   
    'dm_PH',
   # 'rooms',
   # 'baños_desc',
   # 'floor',
   
    #sup descubierta
    #'dm_planta alta',
    #'dm_terraza',
    #'dm_azotea',
    #'dm_balcon',
    #'dm_patio',
        
    #cochera  
    #'dm_cochera',
    #'dm_cocheras',
    #'dm_guarda coche',
    #'dm_guardacoche',
        
     #servicios 
    #'dm_seguridad',
    #'dm_vigilancia', 
    #'dm_caldera',   
    #'dm_calefaccion',
    #'dm_central', 
         
    #amenities 
    #'dm_pileta', 
    #'dm_parrilla',
    #'dm_quincho', 
    #'dm_sum',  
    #'dm_amenities', 
    #'dm_gimnasio',  
      
        
    'dm_d_sup_descubierta',
    'dm_d_cochera',
    'dm_d_servicios',
    'dm_d_amenities'
        
    #'dm_vestidor',
    #'dm_baulera',
    #'dm_suite',
    #'dm_palier',
    #'dm_hall',
    #'dm_estrenar',
    #'dm_condominio',
    #'dm_barrio cerrado',
    #'dm_escuela',
    #'dm_expensa'
    ]

    #District_key
    for loc in dfprop['district_name_key'].unique():
        column_features.append('dm_'+loc) 

    return column_features

# %% [markdown]
# Se generan 3 Dummies para separar los tipos de propiedad

# %%
dfprop=new_dummy_from_included_in_column(dfprop,'property_type','PH')
dfprop=new_dummy_from_included_in_column(dfprop,'property_type','apartment')
dfprop=new_dummy_from_included_in_column(dfprop,'property_type','house')
# Out:
# Cantidad de rows con dm_PH:  5099
# Cantidad de rows con dm_apartment:  62525
# Cantidad de rows con dm_house:  31956

# %%
dfprop['state_name'].unique()
# Out:
# array(['Capital Federal', 'Bs.As. G.B.A. Zona Sur',
#        'Buenos Aires Costa Atlántica', 'Bs.As. G.B.A. Zona Norte',
#        'Santa Fe', 'Córdoba', 'Bs.As. G.B.A. Zona Oeste', 'Misiones',
#        'Entre Ríos', 'Buenos Aires Interior', 'Neuquén', 'San Luis',
#        'Río Negro', 'Salta', 'Mendoza', 'Tucumán', 'Corrientes', 'Chubut'],
#       dtype=object)

# %%
dfprop['description']=dfprop['description'].str.lower()

dfprop=new_dummy_from_included_in_column(dfprop,'description','inmomap')
dfprop=dfprop.loc[dfprop['dm_inmomap']==0]

dfprop=new_dummy_from_included_in_column(dfprop,'description','construccion')
dfprop=dfprop.loc[dfprop['dm_construccion']==0]

dfprop=new_dummy_from_included_in_column(dfprop,'description','obra')
dfprop=dfprop.loc[dfprop['dm_obra']==0]
# Out:
# Cantidad de rows con dm_inmomap:  2532
# Cantidad de rows con dm_construccion:  1625
# Cantidad de rows con dm_obra:  3569

# %%
dfprop=generate_dummies_per_location(dfprop)
# Out:
# Cantidad de rows con dm_Argentina-Capital Federal-Mataderos:  349
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Sur-La Plata:  2602
# Cantidad de rows con dm_Argentina-Capital Federal-Liniers:  308
# Cantidad de rows con dm_Argentina-Buenos Aires Costa Atlántica-Mar del Plata:  6732
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Norte-Vicente López:  3206
# Cantidad de rows con dm_Argentina-Capital Federal-Belgrano:  2358
# Cantidad de rows con dm_Argentina-Santa Fe-Rosario:  6947
# Cantidad de rows con dm_Argentina-Córdoba-Córdoba:  5477
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Norte-San Miguel:  1119
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Norte-San Isidro:  2709
# Cantidad de rows con dm_Argentina-Capital Federal-Palermo:  3140
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Norte-Tigre:  7950
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Oeste-General Rodríguez:  126
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Norte-Pilar:  2811
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Oeste-Morón:  2297
# Cantidad de rows con dm_Argentina-Capital Federal-Flores:  1637
# Cantidad de rows con dm_Argentina-Capital Federal-Boedo:  228
# Cantidad de rows con dm_Argentina-Capital Federal-Las Cañitas:  131
# Cantidad de rows con dm_Argentina-Córdoba-Villa Carlos Paz:  540
# Cantidad de rows con dm_Argentina-Capital Federal-Balvanera:  592
# Cantidad de rows con dm_Argentina-Capital Federal-Caballito:  2001
# Cantidad de rows con dm_Argentina-Capital Federal-Nuñez:  597
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Sur-Berazategui:  392
# Cantidad de rows con dm_Argentina-Misiones-Posadas:  325
# Cantidad de rows con dm_Argentina-Buenos Aires Costa Atlántica-San Bernardo:  109
# Cantidad de rows con dm_Argentina-Capital Federal-San Telmo:  950
# Cantidad de rows con dm_Argentina-Capital Federal-Almagro:  940
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Norte-San Fernando:  913
# Cantidad de rows con dm_Argentina-Buenos Aires Costa Atlántica-Pinamar:  847
# Cantidad de rows con dm_Argentina-Entre Ríos-Colón:  16
# Cantidad de rows con dm_Argentina-Buenos Aires Interior-Luján:  323
# Cantidad de rows con dm_Argentina-Santa Fe-San Lorenzo:  97
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Sur-Lanús:  1493
# Cantidad de rows con dm_Argentina-Córdoba-Punilla:  635
# Cantidad de rows con dm_Argentina-Buenos Aires Costa Atlántica-Villa Gesell:  280
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Sur-Lomas de Zamora:  3020
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Norte-General San Martín:  1090
# Cantidad de rows con dm_Argentina-Capital Federal-Colegiales:  292
# Cantidad de rows con dm_Argentina-Santa Fe-Santa Fe:  321
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Sur-Quilmes:  718
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Oeste-Tres de Febrero:  1033
# Cantidad de rows con dm_Argentina-Capital Federal-Barrio Norte:  984
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Norte-Escobar:  1488
# Cantidad de rows con dm_Argentina-Capital Federal-Barracas:  382
# Cantidad de rows con dm_Argentina-Córdoba-Villa Allende:  82
# Cantidad de rows con dm_Argentina-Buenos Aires Interior-Lobos:  62
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Oeste-La Matanza:  1967
# Cantidad de rows con dm_Argentina-Neuquén-San Martín de los Andes:  59
# Cantidad de rows con dm_Argentina-Capital Federal-Recoleta:  1293
# Cantidad de rows con dm_Argentina-Capital Federal-Villa Crespo:  1168
# Cantidad de rows con dm_Argentina-Capital Federal-Puerto Madero:  568
# Cantidad de rows con dm_Argentina-Capital Federal-Constitución:  190
# Cantidad de rows con dm_Argentina-Capital Federal-Villa Urquiza:  1336
# Cantidad de rows con dm_Argentina-San Luis-Merlo:  86
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Norte-José C Paz:  125
# Cantidad de rows con dm_Argentina-Capital Federal-Saavedra:  456
# Cantidad de rows con dm_Argentina-Buenos Aires Interior-Bahía Blanca:  418
# Cantidad de rows con dm_Argentina-Río Negro-General Roca:  35
# Cantidad de rows con dm_Argentina-Neuquén-Neuquén:  172
# Cantidad de rows con dm_Argentina-Capital Federal-Parque Chas:  36
# Cantidad de rows con dm_Argentina-Capital Federal-Paternal:  145
# Cantidad de rows con dm_Argentina-Capital Federal-Agronomía:  36
# Cantidad de rows con dm_Argentina-Capital Federal-Villa Pueyrredón:  160
# Cantidad de rows con dm_Argentina-Capital Federal-Coghlan:  224
# Cantidad de rows con dm_Argentina-Capital Federal-Parque Centenario:  57
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Oeste-Moreno:  667
# Cantidad de rows con dm_Argentina-Capital Federal-Monserrat:  427
# Cantidad de rows con dm_Argentina-Capital Federal-Floresta:  466
# Cantidad de rows con dm_Argentina-Capital Federal-Villa Luro:  356
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Sur-Almirante Brown:  1376
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Oeste-Ituzaingó:  492
# Cantidad de rows con dm_Argentina-Capital Federal-Villa Devoto:  322
# Cantidad de rows con dm_Argentina-Capital Federal-Boca:  184
# Cantidad de rows con dm_Argentina-Buenos Aires Interior-Rivadavia:  199
# Cantidad de rows con dm_Argentina-Capital Federal-Parque Avellaneda:  47
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Norte-Malvinas Argentinas:  416
# Cantidad de rows con dm_Argentina-Capital Federal-San Cristobal:  324
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Sur-Cañuelas:  41
# Cantidad de rows con dm_Argentina-Salta-Salta:  75
# Cantidad de rows con dm_Argentina-Capital Federal-Abasto:  81
# Cantidad de rows con dm_Argentina-Capital Federal-Versalles:  39
# Cantidad de rows con dm_Argentina-Capital Federal-Villa del Parque:  442
# Cantidad de rows con dm_Argentina-Capital Federal-Retiro:  195
# Cantidad de rows con dm_Argentina-Capital Federal-Parque Patricios:  244
# Cantidad de rows con dm_Argentina-Buenos Aires Interior-General Pueyrredón:  97
# Cantidad de rows con dm_Argentina-Río Negro-San Carlos de Bariloche:  187
# Cantidad de rows con dm_Argentina-Capital Federal-Chacarita:  207
# Cantidad de rows con dm_Argentina-Capital Federal-Congreso:  231
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Oeste-Merlo:  180
# Cantidad de rows con dm_Argentina-Buenos Aires Interior-Tres Arroyos:  74
# Cantidad de rows con dm_Argentina-Santa Fe-Granadero Baigorria:  32
# Cantidad de rows con dm_Argentina-Santa Fe-Funes:  64
# Cantidad de rows con dm_Argentina-Capital Federal-Monte Castro:  59
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Sur-Ezeiza:  471
# Cantidad de rows con dm_Argentina-Capital Federal-Centro / Microcentro:  131
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Sur-Avellaneda:  579
# Cantidad de rows con dm_Argentina-Buenos Aires Interior-Chascomús:  44
# Cantidad de rows con dm_Argentina-Buenos Aires Costa Atlántica-Mar de Ajó:  39
# Cantidad de rows con dm_Argentina-Capital Federal-Once:  120
# Cantidad de rows con dm_Argentina-Capital Federal-Tribunales:  66
# Cantidad de rows con dm_Argentina-Buenos Aires Costa Atlántica-Santa Teresita:  38
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Oeste-Hurlingham:  123
# Cantidad de rows con dm_Argentina-Córdoba-Mendiolaza:  68
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Sur-Esteban Echeverría:  582
# Cantidad de rows con dm_Argentina-Córdoba-Río Ceballos:  34
# Cantidad de rows con dm_Argentina-Capital Federal-Velez Sarsfield:  34
# Cantidad de rows con dm_Argentina-Capital Federal-San Nicolás:  161
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Oeste-Marcos Paz:  77
# Cantidad de rows con dm_Argentina-Mendoza-Mendoza:  54
# Cantidad de rows con dm_Argentina-Córdoba-La Calera:  104
# Cantidad de rows con dm_Argentina-Capital Federal-Parque Chacabuco:  114
# Cantidad de rows con dm_Argentina-Santa Fe-Santo Tomé:  40
# Cantidad de rows con dm_Argentina-Entre Ríos-Paraná:  43
# Cantidad de rows con dm_Argentina-Tucumán-San Miguel de Tucumán:  104
# Cantidad de rows con dm_Argentina-Buenos Aires Costa Atlántica-Miramar:  113
# Cantidad de rows con dm_Argentina-Buenos Aires Interior-Trenque Lauquen:  9
# Cantidad de rows con dm_Argentina-Santa Fe-Roldán:  71
# Cantidad de rows con dm_Argentina-Buenos Aires Costa Atlántica-Costa Esmeralda:  85
# Cantidad de rows con dm_Argentina-Corrientes-Ituzaingó:  461
# Cantidad de rows con dm_Argentina-Buenos Aires Interior-Tandil:  70
# Cantidad de rows con dm_Argentina-Mendoza-San Rafael:  71
# Cantidad de rows con dm_Argentina-Buenos Aires Interior-San Pedro:  6
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Sur-Presidente Perón:  93
# Cantidad de rows con dm_Argentina-Buenos Aires Costa Atlántica-Mar Azul:  29
# Cantidad de rows con dm_Argentina-San Luis-San Luis:  42
# Cantidad de rows con dm_Argentina-Buenos Aires Costa Atlántica-Valeria del Mar:  50
# Cantidad de rows con dm_Argentina-Capital Federal-Pompeya:  40
# Cantidad de rows con dm_Argentina-Capital Federal-Villa General Mitre:  42
# Cantidad de rows con dm_Argentina-Córdoba-Río Cuarto:  50
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Sur-San Vicente:  109
# Cantidad de rows con dm_Argentina-Buenos Aires Interior-San Miguel del Monte:  13
# Cantidad de rows con dm_Argentina-Neuquén-Lácar:  10
# Cantidad de rows con dm_Argentina-Neuquén-Confluencia:  102
# Cantidad de rows con dm_Argentina-Buenos Aires Interior-Coronel Suárez:  19
# Cantidad de rows con dm_Argentina-Capital Federal-Villa Lugano:  147
# Cantidad de rows con dm_Argentina-Buenos Aires Costa Atlántica-Monte Hermoso:  59
# Cantidad de rows con dm_Argentina-Tucumán-Yerba Buena:  18
# Cantidad de rows con dm_Argentina-Bs.As. G.B.A. Zona Sur-Florencio Varela:  33
# Cantidad de rows con dm_Argentina-Buenos Aires Costa Atlántica-Cariló:  52
# Cantidad de rows con dm_Argentina-Capital Federal-Villa Santa Rita:  40
# Cantidad de rows con dm_Argentina-Capital Federal-Villa Ortuzar:  65
# Cantidad de rows con dm_Argentina-Córdoba-Santa María:  139
# Cantidad de rows con dm_Argentina-Córdoba-Villa General Belgrano:  24
# Cantidad de rows con dm_Argentina-Córdoba-Unquillo:  31
# Cantidad de rows con dm_Argentina-Buenos Aires Costa Atlántica-Mar de las Pampas:  44
# Cantidad de rows con dm_Argentina-Capital Federal-Villa Real:  34
# Cantidad de rows con dm_Argentina-Santa Fe-Capitán Bermúdez:  44
# Cantidad de rows con dm_Argentina-Buenos Aires Interior-Balcarce:  32
# Cantidad de rows con dm_Argentina-Neuquén-Villa La Angostura:  20
# Cantidad de rows con dm_Argentina-Córdoba-Santa Rosa de Calamuchita:  22
# Cantidad de rows con dm_Argentina-Córdoba-San Roque:  1
# Cantidad de rows con dm_Argentina-Santa Fe-Rafaela:  2
# Cantidad de rows con dm_Argentina-Entre Ríos-Villa Urquiza:  1
# Cantidad de rows con dm_Argentina-Chubut-Escalante:  32
# Cantidad de rows con dm_Argentina-Chubut-Cushamen:  56
# Cantidad de rows con dm_Argentina-Mendoza-San Roque:  148
# Cantidad de rows con dm_Argentina-Corrientes-Mburucuyá:  58
# Cantidad de rows con dm_Argentina-Córdoba-Malvinas Argentinas:  3

# %%
ambientes_desc = []
for i in range(len(dfprop.index)):
    if re.search(r"\d\s"+'amb', str(dfprop['description'].iloc[i]), flags = re.IGNORECASE):
        ambientes_desc.append(float(re.search(r"\d",re.search(r"\d\s"+'amb', dfprop['description'].iloc[i], flags = re.IGNORECASE).group()).group()))
    else:
        ambientes_desc.append(np.nan)
dfprop['ambientes_desc'] = ambientes_desc

# %%
ambientes_title = []
for i in range(len(dfprop.index)):
    if re.search(r"\d\s"+'amb', str(dfprop['title'].iloc[i]), flags = re.IGNORECASE):
        ambientes_title.append(float(re.search(r"\d",re.search(r"\d\s"+'amb', dfprop['title'].iloc[i], flags = re.IGNORECASE).group()).group()))
    else:
        ambientes_title.append(np.nan)
dfprop['ambientes_title'] = ambientes_title

# %%
dfprop.fillna({'ambientes_title' : dfprop['ambientes_desc']}, inplace = True)
dfprop.fillna({'rooms' : dfprop['ambientes_title']}, inplace = True)
dfprop.loc[dfprop['rooms'] != dfprop['ambientes_title'], 'rooms'] = dfprop.loc[dfprop['rooms'] != dfprop['ambientes_title'], 'ambientes_title']
#descartamos las columnas 'ambientes_title' y 'ambientes_desc' para evitar confusiones
dfprop = dfprop.drop(labels = ['ambientes_title', 'ambientes_desc'], axis = 1)

# %%
dfprop=new_dummy_from_included_in_column(dfprop,'description','monoambiente')
condicion_monoambiente=dfprop['dm_monoambiente']==1
dfprop.loc[condicion_monoambiente,'rooms']=1
# Out:
# Cantidad de rows con dm_monoambiente:  6043

# %%
dfprop.shape
# Out:
# (91854, 193)

# %% [markdown]
# ## Analisis de Outliers

# %%
plot_price_dispersion(dfprop)

# %% [markdown]
# Consideramos un precio mayor a 8000 USD_per_m2 un valor incorrecto

# %%
#Capital Federal
dfprop=dfprop.loc[dfprop['price_usd_per_m2']<8000]
dfprop.shape

#dfprop=dfprop.loc[dfprop['price_usd_per_m2']>1000]
# Out:
# (91809, 193)

# %% [markdown]
# Limpiamos outliers

# %%
dfprop=clean_outliers(dfprop)
plot_price_dispersion(dfprop)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
dfprop['description']=dfprop['description'].str.lower()

dfprop=new_dummy_from_included_in_column(dfprop,'description','planta alta')
dfprop=new_dummy_from_included_in_column(dfprop,'description','terraza')
dfprop=new_dummy_from_included_in_column(dfprop,'description','azotea')
dfprop=new_dummy_from_included_in_column(dfprop,'description','balcon')
dfprop=new_dummy_from_included_in_column(dfprop,'description','patio')


dfprop=new_dummy_from_included_in_column(dfprop,'description','cochera')
dfprop=new_dummy_from_included_in_column(dfprop,'description','cocheras')
dfprop=new_dummy_from_included_in_column(dfprop,'description','guardacoche')
dfprop=new_dummy_from_included_in_column(dfprop,'description','guarda coche')


dfprop=new_dummy_from_included_in_column(dfprop,'description','seguridad')
dfprop=new_dummy_from_included_in_column(dfprop,'description','vigilancia')
dfprop=new_dummy_from_included_in_column(dfprop,'description','caldera')
dfprop=new_dummy_from_included_in_column(dfprop,'description','calefaccion')
dfprop=new_dummy_from_included_in_column(dfprop,'description','central')


dfprop=new_dummy_from_included_in_column(dfprop,'description','pileta')
dfprop=new_dummy_from_included_in_column(dfprop,'description','parrilla')
dfprop=new_dummy_from_included_in_column(dfprop,'description','quincho')
dfprop=new_dummy_from_included_in_column(dfprop,'description','sum')
dfprop=new_dummy_from_included_in_column(dfprop,'description','amenities')
dfprop=new_dummy_from_included_in_column(dfprop,'description','gimnasio')


#dfprop=new_dummy_from_included_in_column(dfprop,'description','vestidor')
#dfprop=new_dummy_from_included_in_column(dfprop,'description','baulera')
#dfprop=new_dummy_from_included_in_column(dfprop,'description','suite')
#dfprop=new_dummy_from_included_in_column(dfprop,'description','palier')
#dfprop=new_dummy_from_included_in_column(dfprop,'description','hall')
#dfprop=new_dummy_from_included_in_column(dfprop,'description','estrenar')
#dfprop=new_dummy_from_included_in_column(dfprop,'description','condominio')
#dfprop=new_dummy_from_included_in_column(dfprop,'description','barrio cerrado')
#dfprop=new_dummy_from_included_in_column(dfprop,'description','monoambiente')
#dfprop=new_dummy_from_included_in_column(dfprop,'description','escuela')
#dfprop=new_dummy_from_included_in_column(dfprop,'description','expensa')
dfprop.shape
# Out:
# Cantidad de rows con dm_planta alta:  9511
# Cantidad de rows con dm_terraza:  20637
# Cantidad de rows con dm_azotea:  687
# Cantidad de rows con dm_balcon:  12341
# Cantidad de rows con dm_patio:  15077
# Cantidad de rows con dm_cochera:  31781
# Cantidad de rows con dm_cocheras:  11333
# Cantidad de rows con dm_guardacoche:  578
# Cantidad de rows con dm_guarda coche:  451
# Cantidad de rows con dm_seguridad:  8154
# Cantidad de rows con dm_vigilancia:  1997
# Cantidad de rows con dm_caldera:  4430
# Cantidad de rows con dm_calefaccion:  3021
# Cantidad de rows con dm_central:  8390
# Cantidad de rows con dm_pileta:  14229
# Cantidad de rows con dm_parrilla:  26339
# Cantidad de rows con dm_quincho:  9503
# Cantidad de rows con dm_sum:  10574
# Cantidad de rows con dm_amenities:  7794
# Cantidad de rows con dm_gimnasio:  5277
# (87737, 213)

# %%
condicion_sup_descubierta=((dfprop['dm_planta alta']==1)|\
                     (dfprop['dm_terraza']==1)|\
                     (dfprop['dm_azotea']==1)|\
                     (dfprop['dm_balcon']==1)|\
                     (dfprop['dm_patio']==1))

dfprop['dm_d_sup_descubierta']=0
dfprop.loc[condicion_sup_descubierta,'dm_d_sup_descubierta']=1

condicion_cochera=((dfprop['dm_cochera']==1)|\
                     (dfprop['dm_cocheras']==1)|\
                     (dfprop['dm_guarda coche']==1)|\
                     (dfprop['dm_guardacoche']==1))

dfprop.loc[condicion_cochera,'dm_d_cochera']=1
dfprop.loc[~condicion_cochera,'dm_d_cochera']=0

condicion_servicios=((dfprop['dm_seguridad']==1)|\
                     (dfprop['dm_vigilancia']==1)|\
                     (dfprop['dm_caldera']==1)|\
                     (dfprop['dm_central']==1)|\
                     (dfprop['dm_calefaccion']==1))

dfprop.loc[condicion_servicios,'dm_d_servicios']=1
dfprop.loc[~condicion_servicios,'dm_d_servicios']=0

condicion_amenities=((dfprop['dm_pileta']==1)|\
                     (dfprop['dm_parrilla']==1)|\
                     (dfprop['dm_quincho']==1)|\
                     (dfprop['dm_sum']==1)|\
                     (dfprop['dm_amenities']==1)|\
                     (dfprop['dm_gimnasio']==1))
 
dfprop.loc[condicion_amenities,'dm_d_amenities']=1
dfprop.loc[~condicion_amenities,'dm_d_amenities']=0


dfprop.drop(['dm_planta alta',
    'dm_terraza',
    'dm_azotea',
    'dm_balcon',
    'dm_patio', 
    'dm_cochera',
    'dm_cocheras',
    'dm_guarda coche',
    'dm_guardacoche',
    'dm_seguridad',
    'dm_vigilancia', 
    'dm_caldera',   
    'dm_calefaccion',
    'dm_central', 
    'dm_pileta', 
    'dm_parrilla',
    'dm_quincho', 
    'dm_sum',  
    'dm_amenities', 
    'dm_gimnasio',],axis=1,inplace=True)

# %%
dfprop_targets=dfprop.loc[:,'price_usd_per_m2']

dfprop_features= dfprop.loc[:,getFeaturers(dfprop)]

# %%
dfprop_features.columns
# Out:
# Index(['dm_house', 'dm_apartment', 'dm_PH', 'dm_d_sup_descubierta',
#        'dm_d_cochera', 'dm_d_servicios', 'dm_d_amenities',
#        'dm_Argentina-Capital Federal-Mataderos',
#        'dm_Argentina-Bs.As. G.B.A. Zona Sur-La Plata',
#        'dm_Argentina-Capital Federal-Liniers',
#        ...
#        'dm_Argentina-Neuquén-Villa La Angostura',
#        'dm_Argentina-Córdoba-Santa Rosa de Calamuchita',
#        'dm_Argentina-Santa Fe-Capitán Bermúdez',
#        'dm_Argentina-Santa Fe-Rafaela', 'dm_Argentina-Corrientes-Ituzaingó',
#        'dm_Argentina-Chubut-Escalante', 'dm_Argentina-Chubut-Cushamen',
#        'dm_Argentina-Mendoza-San Roque', 'dm_Argentina-Corrientes-Mburucuyá',
#        'dm_Argentina-Córdoba-Malvinas Argentinas'],
#       dtype='object', length=163)

# %%
#PRIMER SEPARACION HOLDOUT - SAMPLE 100
X, X_holdout, y, y_holdout = train_test_split(dfprop_features, dfprop_targets, test_size=0.2, random_state=53)
print('Hold out')
print(X.shape,y.shape)
print(X_holdout.shape, y_holdout.shape)
# Out:
# Hold out
# (70189, 163) (70189,)
# (17548, 163) (17548,)

# %% [markdown]
# ## Linear Regression

# %%
def plot_coef(name,coef,coef_color,r2):
    plt.plot(coef, color=coef_color, linewidth=2,label=name+' coefficients')  
    plt.legend(loc='best')
    fig_size = plt.rcParams["figure.figsize"]
    # Set figure width to 12 and height to 9
    fig_size[0] = 10
    fig_size[1] = 5
    plt.rcParams["figure.figsize"] = fig_size
    plt.title(name+" R^2: %.4f"% r2)
    plt.show()

# %%
def Linear_Regression(X_train,y_train):
    '''ordinaria'''
    # en K partes para realizar la validación cruzada
    kf = KFold(n_splits=10, shuffle=True, random_state=12)

    # Instanciamos los modelos
    lm = LinearRegression()

    # Hacemos los fits respectivos
    lm.fit(X_train, y_train)

    # Calculamos el R2
    print(" Score Train Lineal: %.4f\n" % lm.score(X_train, y_train))

    # Calculamos el RMSE
    y_pred_tr_lm = lm.predict(X_train)

    rmse = lambda y, y_pred: np.sqrt(mean_squared_error(y, y_pred))

    print(" Train RMSE lineal   : %.2f \n" % rmse(y_train,y_pred_tr_lm))
    plot_coef('Linear Reg',lm.coef_,'blue',  lm.score(X_train, y_train))
    return lm

# %% [markdown]
# ## Ridge

# %%
def Ridge_Regression(X_train,y_train):
    '''ridge'''
    al_ridge = np.linspace(0.02, 1.5, 200)
    kf = KFold(n_splits=10, shuffle=True)
    # Instanciamos los modelos

    lm_ridge_cv= RidgeCV(alphas=al_ridge, cv=kf, normalize=False)

    # Hacemos los fits respectivos
    lm_ridge_cv.fit(X_train, y_train)

    print('Alpha Ridge:',lm_ridge_cv.alpha_,'\n')
    # Calculamos el R2

    print("Score Train Ridge : %.4f\n" % lm_ridge_cv.score(X_train, y_train))

    # Calculamos el RMSE

    y_pred_tr_ridge = lm_ridge_cv.predict(X_train)

    rmse = lambda y, y_pred: np.sqrt(mean_squared_error(y, y_pred))

    print("Train RMSE Ridge    : %.2f \n" % rmse(y_train,y_pred_tr_ridge))
    
    plot_coef('Ridge',lm_ridge_cv.coef_,'red',  lm_ridge_cv.score(X_train, y_train))
    return lm_ridge_cv

# %% [markdown]
# ## LASSO

# %%
def Lasso_Regression(X_train,y_train):
    al_lasso = np.linspace(0.001, 1, 500)
    kf = KFold(n_splits=10, shuffle=True, random_state=12)
    al_lasso
    # Instanciamos los modelos

    lm_lasso_cv = LassoCV(alphas=al_lasso, cv=kf, normalize=False)

    # Hacemos los fits respectivos
    lm_lasso_cv.fit(X_train, y_train)

    print('Alpha LASSO:',lm_lasso_cv.alpha_,'\n')
    # Calculamos el R2
    print("Score Train Lasso : %.4f\n" %  lm_lasso_cv.score(X_train, y_train))

    # Calculamos el RMSE

    y_pred_tr_lasso = lm_lasso_cv.predict(X_train)

    rmse = lambda y, y_pred: np.sqrt(mean_squared_error(y, y_pred))

    print("Train RMSE Lasso    : %.2f \n" % rmse(y_train,y_pred_tr_lasso))
    
    plot_coef('Lasso',lm_lasso_cv.coef_,'green',  lm_lasso_cv.score(X_train, y_train))
    return lm_lasso_cv

# %% [markdown]
# ## Test All Models

# %%
"""model_lm=Linear_Regression(X_train,y_train)
model_ridge=Ridge_Regression(X_train,y_train)"""
model_lasso=Lasso_Regression(X,y)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# Alpha LASSO: 0.001
#
# Score Train Lasso : 0.6726
#
# Train RMSE Lasso    : 485.69

# %%
"""import pickle
with open('ridge.pkl', 'wb') as f:
    pickle.dump({'model':model_ridge}, f)
with open('linear.pkl', 'wb') as f:
    pickle.dump({'model':model_lm}, f)
with open('lasso.pkl', 'wb') as f:
    pickle.dump({'model':model_lasso}, f)"""
# Out:
# "import pickle\nwith open('ridge.pkl', 'wb') as f:\n    pickle.dump({'model':model_ridge}, f)\nwith open('linear.pkl', 'wb') as f:\n    pickle.dump({'model':model_lm}, f)\nwith open('lasso.pkl', 'wb') as f:\n    pickle.dump({'model':model_lasso}, f)"

# %%
"""with open('ridge.pkl', 'wb') as fp:
    model = pickle.load(fp)

ridge = model['model']"""
# Out:
# "with open('ridge.pkl', 'wb') as fp:\n    model = pickle.load(fp)\n\nridge = model['model']"

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(20,2)})
sns.heatmap(pd.concat([dfprop_features.loc[:,  ['dm_house', 'dm_apartment',   
    'dm_PH','dm_d_sup_descubierta',
    'dm_d_cochera',
    'dm_d_servicios',
    'dm_d_amenities']], pd.DataFrame(dfprop_targets, columns=['price_usd_per_m2'])], axis=1).corr().iloc[[-1]], annot=True);

# %%
"""#Reg lineal
print(" Score Train Lineal: %.4f\n" % model_lm.score(X_test, y_test))

# Calculamos el RMSE
y_pred_test_lm = model_lm.predict(X_test)

rmse = lambda y_test, y_pred_test_lm: np.sqrt(mean_squared_error(y_test, y_pred_test_lm))

print(" Train RMSE lineal   : %.2f \n" % rmse(y_test,y_pred_test_lm))
plot_coef('Linear Reg',model_lm.coef_,'blue',  model_lm.score(X_test, y_test))
"""
# Out:
# '#Reg lineal\nprint(" Score Train Lineal: %.4f\n" % model_lm.score(X_test, y_test))\n\n# Calculamos el RMSE\ny_pred_test_lm = model_lm.predict(X_test)\n\nrmse = lambda y_test, y_pred_test_lm: np.sqrt(mean_squared_error(y_test, y_pred_test_lm))\n\nprint(" Train RMSE lineal   : %.2f \n" % rmse(y_test,y_pred_test_lm))\nplot_coef(\'Linear Reg\',model_lm.coef_,\'blue\',  model_lm.score(X_test, y_test))\n'

# %%
"""#Ridge
print(" Score Train Lineal: %.4f\n" % model_ridge.score(X_test, y_test))

# Calculamos el RMSE
y_pred_test_ridge = model_ridge.predict(X_test)

rmse = lambda y_test, y_pred_test_ridge: np.sqrt(mean_squared_error(y_test, y_pred_test_ridge))

print(" Train RMSE lineal   : %.2f \n" % rmse(y_test,y_pred_test_ridge))
plot_coef('Linear Reg',model_ridge.coef_,'blue',  model_ridge.score(X_test, y_test))

"""
# Out:
# '#Ridge\nprint(" Score Train Lineal: %.4f\n" % model_ridge.score(X_test, y_test))\n\n# Calculamos el RMSE\ny_pred_test_ridge = model_ridge.predict(X_test)\n\nrmse = lambda y_test, y_pred_test_ridge: np.sqrt(mean_squared_error(y_test, y_pred_test_ridge))\n\nprint(" Train RMSE lineal   : %.2f \n" % rmse(y_test,y_pred_test_ridge))\nplot_coef(\'Linear Reg\',model_ridge.coef_,\'blue\',  model_ridge.score(X_test, y_test))\n\n'

# %%
"""#Lasso
print(" Score Train Lineal: %.4f\n" % model_lasso.score(X_test, y_test))

# Calculamos el RMSE
y_pred_test_lasso = model_lasso.predict(X_test)

rmse = lambda y_test, y_pred_test_lasso: np.sqrt(mean_squared_error(y_test, y_pred_test_lasso))

print(" Train RMSE lineal   : %.2f \n" % rmse(y_test,y_pred_test_lasso))
plot_coef('Linear Reg',model_lasso.coef_,'blue',  model_lasso.score(X_test, y_test))"""
# Out:
# '#Lasso\nprint(" Score Train Lineal: %.4f\n" % model_lasso.score(X_test, y_test))\n\n# Calculamos el RMSE\ny_pred_test_lasso = model_lasso.predict(X_test)\n\nrmse = lambda y_test, y_pred_test_lasso: np.sqrt(mean_squared_error(y_test, y_pred_test_lasso))\n\nprint(" Train RMSE lineal   : %.2f \n" % rmse(y_test,y_pred_test_lasso))\nplot_coef(\'Linear Reg\',model_lasso.coef_,\'blue\',  model_lasso.score(X_test, y_test))'

# %%
"""import pickle
with open(r'final_model.pkl', 'rb') as fp:
    model = pickle.load(fp)

final_model = model['model']"""
final_model = model_lasso.fit(X, y)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
#Exportamos el modelo final
with open('final_model.pkl', 'wb') as f:
    pickle.dump({'model':final_model}, f)
"""with open('final_model.pkl', 'wb') as fp:
    model = pickle.load(fp)

final_model = model['model']"""
# Out:
# "with open('final_model.pkl', 'wb') as fp:\n    model = pickle.load(fp)\n\nfinal_model = model['model']"

# %%
#Lasso Final
print(" Score Lasso: %.4f\n" % model_lasso.score(X, y))

# Calculamos el RMSE
y_pred_lasso = model_lasso.predict(X)

rmse = lambda y, y_pred_lasso: np.sqrt(mean_squared_error(y, y_pred_lasso))

print(" RMSE    : %.2f \n" % rmse(y,y_pred_lasso))
plot_coef('Lasso',model_lasso.coef_,'blue',  model_lasso.score(X, y))
# Out:
#  Score Lasso: 0.6726
#
#  RMSE    : 485.69

# %%
#Lasso Test contra Holdout
print(" Score Lasso: %.4f\n" % model_lasso.score(X_holdout, y_holdout))

# Calculamos el RMSE
y_pred_ho_lasso = model_lasso.predict(X_holdout)

rmse = lambda y_holdout, y_pred_ho_lasso: np.sqrt(mean_squared_error(y_holdout, y_pred_ho_lasso))

print(" RMSE    : %.2f \n" % rmse(y_holdout,y_pred_ho_lasso))
plot_coef('Lasso',model_lasso.coef_,'blue',  model_lasso.score(X_holdout, y_holdout))
# Out:
#  Score Lasso: 0.6769
#
#  RMSE    : 485.23

# %%
"""# Graficamos los resultados
plt.plot(y,y, '-.', c='grey')
plt.xlabel("Predicciones ")
plt.ylabel("Valores reales")

sns.set_style('ticks')

plt.scatter(y_pred_tr_lm_a,y_test, s=30, c='r', marker='+', zorder=10)
plt.show()"""

# %%
#calculamos precios usando el precio usd/m2, que es el que usamos en nuestro modelo
price_calc = []
for x in range(len(dfprop.index)):
    price_calc.append(dfprop.iloc[x].loc['surface_total_in_m2']*dfprop.iloc[x].loc['price_usd_per_m2'])
dfprop['price_calc'] = price_calc

# %%
dfportafolio = dfprop.sample(n = 100, random_state=1)
dfportafolio['price_calc'].sum()
# Out:
# 22235086.58766866

# %%
y_portafolio=dfportafolio.loc[:,'price_usd_per_m2']

x_portafolio= dfportafolio.loc[:,getFeaturers(dfportafolio)]

# %%
y_portafolio_predict = final_model.predict(x_portafolio)

# %%
# Graficamos los resultados

sns.set_style('darkgrid')
sns.set_palette('Set2', 8, .75)
plot_67 = sns.lmplot(x='y_pred_lasso', y='y', data = df_select, height = 8, aspect = 1, palette = 'Set2')
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plot_67.savefig('plot_67')

# %%
df_select  = pd.DataFrame()
df_select['y'] = y
df_select['y_pred_lasso'] = y_pred_lasso
df_select
# Out:
#                  y  y_pred_lasso
# 21627  1311.605723   1718.152707
# 52376  1466.666667   1849.680402
# 87195   625.726942    687.158812
# 53764   792.079208    971.942623
# 10503  1882.941672   1703.150138
# 72908  3205.128205   3101.753910
# 17254   892.388451   1434.684370
# 37042  1257.142857   1283.942929
# 11354  1888.864122   1747.037918
# 41859   875.000000   1181.476957
# 91725  2077.922078   1999.445147
# 2696   1036.478530    872.167827
# 435    2019.230769   2123.515767
# 8824   1421.290020   1004.809856
# 10458  1500.000000   1070.177199
# 74656  1201.044386   1820.175919
# 73527  1492.478303   1681.467228
# 29396  2460.532274   2530.656652
# 70875   692.307692    971.942623
# 87071  2962.962963   2663.599444
# 37728  3146.853147   3093.377049
# 40297  1897.500000   1747.037918
# 80497  3181.818182   2352.798274
# 10029    63.843056    476.702003
# 55670  2236.666667   2150.105452
# 16586  3125.000000   3004.109114
# 770    1230.769231   1061.800338
# 1007   2894.736842   2308.524781
# 71148  1329.787234    934.869429
# 25488  1250.000000   1865.707867
# ...            ...           ...
# 46786  3027.027027   2872.471403
# 4265   3340.909091   1813.638474
# 80791  1872.093023   2009.600621
# 70787  3666.666667   2507.043903
# 13909  1924.731183   1868.225729
# 3315   1935.925370   1611.495112
# 43073  1735.849057   1976.320425
# 16331  1230.769231    745.121016
# 53094  2602.739726   1537.597414
# 27887  6436.781609   5899.880093
# 48657  1296.196188   1057.411607
# 13863  1352.941176   1655.768604
# 80101  2050.847458   2308.524781
# 30164  2250.000000   1807.745663
# 71748  1727.272727   2045.305148
# 30931  1625.000000   2144.301873
# 70892  3533.333333   2507.043903
# 69586  2323.684211   2547.218788
# 11956  2012.987013   1933.106081
# 8380   1215.384615   1079.502751
# 61260  3640.776699   3057.480418
# 24483  1035.233916   1243.933850
# 39240  2333.333333   1987.342943
# 9233   1881.443299   3252.834678
# 89153  2910.287838   3023.552171
# 49131  1037.037037   1834.219121
# 58217  1501.601729   1090.733565
# 37490  2916.666667   3031.929033
# 60716  2555.555556   2418.924855
# 59398  2536.384401   2680.406807
#
# [70189 rows x 2 columns]

# %%
dfportafolio['price_usd_per_m2_predicted'] = y_portafolio_predict
price_predicted = []
for x in range(len(dfportafolio.index)):
    price_predicted.append(dfportafolio.iloc[x].loc['surface_total_in_m2']*dfportafolio.iloc[x].loc['price_usd_per_m2_predicted'])
dfportafolio['price_predicted'] = price_predicted
print("La diferencia entre el valor de mercado de nuestro portafolio y el valor modelado es de: %.2f \n" % (dfportafolio['price_calc'].sum() - dfportafolio['price_predicted'].sum()))
# Out:
# La diferencia entre el valor de mercado de nuestro portafolio y el valor modelado es de: -1633282.38

# %%
#usamos el modelo para predecir los precios/m2 de todo el df y obtener el precio de cada propiedad según nuestro modelo
y_dfprop_predict = model_lasso.predict(dfprop_features)
dfprop['price_usd_per_m2_predicted'] = y_dfprop_predict
price_predicted = []
for x in range(len(dfprop.index)):
    price_predicted.append(dfprop.iloc[x].loc['surface_total_in_m2']*dfprop.iloc[x].loc['price_usd_per_m2_predicted'])
dfprop['price_predicted'] = price_predicted

# %%
# Graficamos los precios modelados

sns.set_style('darkgrid')
sns.set_palette('Set2', 8, .75)
sns.lmplot(x='price_predicted', y='price_calc', data = dfprop, height = 8, aspect = 1, palette = 'Set2')
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
cota_sup = []
for x in range(len(dfprop.index)):
    cota_sup.append(dfprop.iloc[x].loc['price_predicted']+500)
dfprop['cota_superior'] = price_predicted

cota_inf = []
for x in range(len(dfprop.index)):
    cota_inf.append(dfprop.iloc[x].loc['price_predicted']-500)
dfprop['cota_inferior'] = price_predicted

# %%
df_precios = dfprop.loc[:,['price_calc','price_predicted','cota_inferior','cota_superior']]
df_precios = df_precios.apply(lambda x: x/10000)
# Graficamos los precios modelados

sns.set_style('darkgrid')
sns.set_palette('Set2', 8, .75)
sns.lmplot(x='price_predicted', y='price_calc', data = df_precios.loc[((df_precios['price_calc']<6000)&(df_precios['price_predicted']<6000))], height = 8, aspect = 1, palette = 'Set2')
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
rango = []
for x in range(len(df_precios.index)):
    if (df_precios.iloc[x].loc['price_calc'] < df_precios.iloc[x].loc['cota_inferior'])\
    & (df_precios.iloc[x].loc['price_calc'] > (df_precios.iloc[x].loc['cota_inferior']-0.075)):
        rango.append(x)
df_a_comprar = df_precios.iloc[rango]
# Out:
#        price_calc  price_predicted  cota_inferior  cota_superior
# 134      9.461472         9.515908       9.515908       9.515908
# 320     12.000000        12.040591      12.040591      12.040591
# 558      8.700000         8.711035       8.711035       8.711035
# 796      5.000000         5.073486       5.073486       5.073486
# 883     22.450000        22.467030      22.467030      22.467030
# 1077     7.338004         7.412878       7.412878       7.412878
# 1217    10.146368        10.209489      10.209489      10.209489
# 1385     0.158927         0.180014       0.180014       0.180014
# 1424     6.862269         6.904073       6.904073       6.904073
# 1472    15.291219        15.350377      15.350377      15.350377
# 1541    10.170367        10.218325      10.218325      10.218325
# 1734     8.379398         8.449220       8.449220       8.449220
# 1953     7.856668         7.910084       7.910084       7.910084
# 2033    14.678767        14.738151      14.738151      14.738151
# 2210     6.367337         6.389575       6.389575       6.389575
# 2412     0.165762         0.168147       0.168147       0.168147
# 2422     0.167824         0.168147       0.168147       0.168147
# 2423     0.145630         0.174781       0.174781       0.174781
# 2433     0.111652         0.168147       0.168147       0.168147
# 2476     0.136286         0.170465       0.170465       0.170465
# 2478     0.153774         0.168147       0.168147       0.168147
# 2479     0.104276         0.114170       0.114170       0.114170
# 2514     0.149255         0.180014       0.180014       0.180014
# 2566     0.135154         0.137098       0.137098       0.137098
# 2568     0.104276         0.126874       0.126874       0.126874
# 2569     0.117943         0.120241       0.120241       0.120241
# 2661     5.514569         5.548842       5.548842       5.548842
# 2739     3.989278         4.035521       4.035521       4.035521
# 2910    10.700000        10.717250      10.717250      10.717250
# 2942     4.500000         4.545814       4.545814       4.545814
# ...           ...              ...            ...            ...
# 88690   14.900000        14.974096      14.974096      14.974096
# 89005   11.000000        11.059006      11.059006      11.059006
# 89010   11.000000        11.059006      11.059006      11.059006
# 89105    8.618400         8.683101       8.683101       8.683101
# 89163    6.500000         6.505997       6.505997       6.505997
# 89181    7.200000         7.225661       7.225661       7.225661
# 89508    8.520729         8.593275       8.593275       8.593275
# 89509    8.520729         8.593275       8.593275       8.593275
# 89510    8.520729         8.593275       8.593275       8.593275
# 89540   36.000000        36.041831      36.041831      36.041831
# 89651    8.967779         8.980380       8.980380       8.980380
# 89695    8.967779         8.980380       8.980380       8.980380
# 89698    8.967779         8.980380       8.980380       8.980380
# 89871   17.500000        17.542474      17.542474      17.542474
# 89924    5.200000         5.241114       5.241114       5.241114
# 90091   10.900000        10.901798      10.901798      10.901798
# 90137   10.638700        10.648813      10.648813      10.648813
# 90152    9.500000         9.505409       9.505409       9.505409
# 90265    7.600000         7.602997       7.602997       7.602997
# 90414    9.750000         9.762485       9.762485       9.762485
# 90553    7.800000         7.861837       7.861837       7.861837
# 90882    6.800000         6.818589       6.818589       6.818589
# 91189    7.521942         7.551234       7.551234       7.551234
# 91243    7.483805         7.551234       7.551234       7.551234
# 91446   26.767124        26.788592      26.788592      26.788592
# 91447   20.712655        20.729268      20.729268      20.729268
# 91453   26.521689        26.549447      26.549447      26.549447
# 91464   11.323867        11.335719      11.335719      11.335719
# 91541    5.879871         5.942414       5.942414       5.942414
# 91542    6.370977         6.403916       6.403916       6.403916
#
# [852 rows x 4 columns]

# %%
df_a_comprar = df_a_comprar.join(dfprop.loc[:,['operation_type','district_name_key','dm_d_servicios']])
df_a_comprar
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#        price_calc  price_predicted  cota_inferior  cota_superior  \
# 134      9.461472         9.515908       9.515908       9.515908
# 320     12.000000        12.040591      12.040591      12.040591
# 558      8.700000         8.711035       8.711035       8.711035
# 796      5.000000         5.073486       5.073486       5.073486
# 883     22.450000        22.467030      22.467030      22.467030
# 1077     7.338004         7.412878       7.412878       7.412878
# 1217    10.146368        10.209489      10.209489      10.209489
# 1385     0.158927         0.180014       0.180014       0.180014
# 1424     6.862269         6.904073       6.904073       6.904073
# 1472    15.291219        15.350377      15.350377      15.350377
# 1541    10.170367        10.218325      10.218325      10.218325
# 1734     8.379398         8.449220       8.449220       8.449220
# 1953     7.856668         7.910084       7.910084       7.910084
# 2033    14.678767        14.738151      14.738151      14.738151
# 2210     6.367337         6.389575       6.389575       6.389575
# 2412     0.165762         0.168147       0.168147       0.168147
# 2422     0.167824         0.168147       0.168147       0.168147
# 2423     0.145630         0.174781       0.174781       0.174781
# 2433     0.111652         0.168147       0.168147       0.168147
# 2476     0.136286         0.170465       0.170465       0.170465
# 2478     0.153774         0.168147       0.168147       0.168147
# 2479     0.104276         0.114170       0.114170       0.114170
# 2514     0.149255         0.180014       0.180014       0.180014
# 2566     0.135154         0.137098       0.137098       0.137098
# 2568     0.104276         0.126874       0.126874       0.126874
# 2569     0.117943         0.120241       0.120241       0.120241
# 2661     5.514569         5.548842       5.548842       5.548842
# 2739     3.989278         4.035521       4.035521       4.035521
# 2910    10.700000        10.717250      10.717250      10.717250
# 2942     4.500000         4.545814       4.545814       4.545814
# ...           ...              ...            ...            ...
# 88690   14.900000        14.974096      14.974096      14.974096
# 89005   11.000000        11.059006      11.059006      11.059006
# 89010   11.000000        11.059006      11.059006      11.059006
# 89105    8.618400         8.683101       8.683101       8.683101
# 89163    6.500000         6.505997       6.505997       6.505997
# 89181    7.200000         7.225661       7.225661       7.225661
# 89508    8.520729         8.593275       8.593275       8.593275
# 89509    8.520729         8.593275       8.593275       8.593275
# 89510    8.520729         8.593275       8.593275       8.593275
# 89540   36.000000        36.041831      36.041831      36.041831
# 89651    8.967779         8.980380       8.980380       8.980380
# 89695    8.967779         8.980380       8.980380       8.980380
# 89698    8.967779         8.980380       8.980380       8.980380
# 89871   17.500000        17.542474      17.542474      17.542474
# 89924    5.200000         5.241114       5.241114       5.241114
# 90091   10.900000        10.901798      10.901798      10.901798
# 90137   10.638700        10.648813      10.648813      10.648813
# 90152    9.500000         9.505409       9.505409       9.505409
# 90265    7.600000         7.602997       7.602997       7.602997
# 90414    9.750000         9.762485       9.762485       9.762485
# 90553    7.800000         7.861837       7.861837       7.861837
# 90882    6.800000         6.818589       6.818589       6.818589
# 91189    7.521942         7.551234       7.551234       7.551234
# 91243    7.483805         7.551234       7.551234       7.551234
# 91446   26.767124        26.788592      26.788592      26.788592
# 91447   20.712655        20.729268      20.729268      20.729268
# 91453   26.521689        26.549447      26.549447      26.549447
# 91464   11.323867        11.335719      11.335719      11.335719
# 91541    5.879871         5.942414       5.942414       5.942414
# 91542    6.370977         6.403916       6.403916       6.403916
#
#        operation_type                                  district_name_key  \
# 134               NaN                         Argentina-Santa Fe-Rosario
# 320               NaN                  Argentina-Capital Federal-Almagro
# 558               NaN             Argentina-Bs.As. G.B.A. Zona Sur-Lanús
# 796               NaN  Argentina-Buenos Aires Costa Atlántica-Mar del...
# 883               NaN                 Argentina-Capital Federal-Barracas
# 1077              NaN                         Argentina-Santa Fe-Rosario
# 1217              NaN                  Argentina-Capital Federal-Almagro
# 1385              NaN           Argentina-Bs.As. G.B.A. Zona Oeste-Morón
# 1424              NaN                  Argentina-Capital Federal-Almagro
# 1472              NaN             Argentina-Capital Federal-Barrio Norte
# 1541              NaN                Argentina-Capital Federal-Caballito
# 1734              NaN           Argentina-Bs.As. G.B.A. Zona Oeste-Morón
# 1953              NaN          Argentina-Bs.As. G.B.A. Zona Oeste-Moreno
# 2033              NaN                 Argentina-Capital Federal-Recoleta
# 2210              NaN           Argentina-Bs.As. G.B.A. Zona Oeste-Morón
# 2412              NaN           Argentina-Bs.As. G.B.A. Zona Oeste-Morón
# 2422              NaN           Argentina-Bs.As. G.B.A. Zona Oeste-Morón
# 2423              NaN           Argentina-Bs.As. G.B.A. Zona Oeste-Morón
# 2433              NaN           Argentina-Bs.As. G.B.A. Zona Oeste-Morón
# 2476              NaN      Argentina-Bs.As. G.B.A. Zona Oeste-La Matanza
# 2478              NaN           Argentina-Bs.As. G.B.A. Zona Oeste-Morón
# 2479              NaN                 Argentina-Córdoba-Villa Carlos Paz
# 2514              NaN           Argentina-Bs.As. G.B.A. Zona Oeste-Morón
# 2566              NaN                 Argentina-Córdoba-Villa Carlos Paz
# 2568              NaN                 Argentina-Córdoba-Villa Carlos Paz
# 2569              NaN                 Argentina-Córdoba-Villa Carlos Paz
# 2661              NaN           Argentina-Bs.As. G.B.A. Zona Oeste-Morón
# 2739              NaN           Argentina-Bs.As. G.B.A. Zona Oeste-Morón
# 2910              NaN                 Argentina-Capital Federal-Recoleta
# 2942              NaN           Argentina-Bs.As. G.B.A. Zona Oeste-Morón
# ...               ...                                                ...
# 88690             NaN   Argentina-Bs.As. G.B.A. Zona Sur-Almirante Brown
# 89005             NaN                 Argentina-Capital Federal-Belgrano
# 89010             NaN                 Argentina-Capital Federal-Belgrano
# 89105             NaN            Argentina-Capital Federal-Villa Urquiza
# 89163             NaN                     Argentina-Capital Federal-Boca
# 89181             NaN                          Argentina-Córdoba-Córdoba
# 89508             NaN             Argentina-Capital Federal-Villa Crespo
# 89509             NaN             Argentina-Capital Federal-Villa Crespo
# 89510             NaN             Argentina-Capital Federal-Villa Crespo
# 89540             NaN    Argentina-Bs.As. G.B.A. Zona Norte-San Fernando
# 89651             NaN                          Argentina-Córdoba-Córdoba
# 89695             NaN                          Argentina-Córdoba-Córdoba
# 89698             NaN                          Argentina-Córdoba-Córdoba
# 89871             NaN  Argentina-Bs.As. G.B.A. Zona Norte-General San...
# 89924             NaN  Argentina-Buenos Aires Costa Atlántica-Mar del...
# 90091             NaN  Argentina-Bs.As. G.B.A. Zona Norte-General San...
# 90137             NaN             Argentina-Capital Federal-Barrio Norte
# 90152             NaN                Argentina-Capital Federal-Caballito
# 90265             NaN  Argentina-Bs.As. G.B.A. Zona Norte-General San...
# 90414             NaN            Argentina-Capital Federal-Villa Urquiza
# 90553             NaN          Argentina-Bs.As. G.B.A. Zona Sur-La Plata
# 90882             NaN      Argentina-Bs.As. G.B.A. Zona Oeste-La Matanza
# 91189             NaN                Argentina-Capital Federal-San Telmo
# 91243             NaN                Argentina-Capital Federal-San Telmo
# 91446             NaN                 Argentina-Capital Federal-Recoleta
# 91447             NaN                 Argentina-Capital Federal-Recoleta
# 91453             NaN                 Argentina-Capital Federal-Belgrano
# 91464             NaN                 Argentina-Capital Federal-Belgrano
# 91541             NaN                Argentina-Capital Federal-Balvanera
# 91542             NaN                   Argentina-Capital Federal-Flores
#
#        dm_d_servicios
# 134               0.0
# 320               0.0
# 558               0.0
# 796               0.0
# 883               0.0
# 1077              0.0
# 1217              0.0
# 1385              0.0
# 1424              0.0
# 1472              0.0
# 1541              0.0
# 1734              0.0
# 1953              0.0
# 2033              0.0
# 2210              0.0
# 2412              0.0
# 2422              0.0
# 2423              0.0
# 2433              0.0
# 2476              0.0
# 2478              0.0
# 2479              0.0
# 2514              0.0
# 2566              1.0
# 2568              0.0
# 2569              0.0
# 2661              0.0
# 2739              0.0
# 2910              0.0
# 2942              0.0
# ...               ...
# 88690             0.0
# 89005             1.0
# 89010             1.0
# 89105             0.0
# 89163             1.0
# 89181             1.0
# 89508             0.0
# 89509             0.0
# 89510             0.0
# 89540             0.0
# 89651             1.0
# 89695             1.0
# 89698             1.0
# 89871             0.0
# 89924             0.0
# 90091             0.0
# 90137             0.0
# 90152             0.0
# 90265             1.0
# 90414             1.0
# 90553             0.0
# 90882             0.0
# 91189             0.0
# 91243             0.0
# 91446             0.0
# 91447             0.0
# 91453             1.0
# 91464             1.0
# 91541             0.0
# 91542             0.0
#
# [852 rows x 7 columns]

# %%
df_a_comprar = df_a_comprar.join(dfprop.loc[:,['property_type']])

# %%
df_a_comprar['price_calc'].describe()
# Out:
# count    852.000000
# mean      11.612810
# std        9.094961
# min        0.104276
# 25%        6.998128
# 50%        8.958889
# 75%       13.242895
# max       98.000000
# Name: price_calc, dtype: float64
