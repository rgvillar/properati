# %% [markdown]
# # Desafio 1: Properti

# %% [markdown]
# ## Objetivos:
# -  Efectuar una limpieza del dataset provisto. Particularmente, deberá diseñar estrategias para lidiar con los datos perdidos en ciertas variables.
#
# -  Realizar un análisis descriptivo de las principales variables.
#
# - Crear nuevas columnas a partir de las características dadas que puedan tener valor predictivo.

# %% [markdown]
# ## Preparacion de ambiente
# ### Importar Librerias
# **Numpy** y **Pandas** son importadas para administrar todas las operaciones analiticas
#
# **IPython** es utilizados para administrar la visualizacion de los datos

# %%
import numpy as np
import pandas as pd
from IPython.display import display

# %% [markdown]
# ### Importar archivo CSV
# Utilizando Pandas importamos el archivo CSV considerando la comma como delimitador

# %%
dfprop=pd.read_csv(filepath_or_buffer='properatti.csv',delimiter=',',index_col = 0 )

# %% [markdown]
# ## Visualizacion
# ### Visualizar la forma del Dataframe
# Se utilizara la funcion nativa **shape** de la clase DataFrame para visualizar:
# - Cantidad de observaciones
# - Cantidad de variables

# %%
dfprop.shape
# Out:
# (121220, 25)

# %% [markdown]
# ### Visualizar estructura del Dataframe
# Se utilizara la funcion nativa **info()** de la clase DataFrame para visualizar:
# - Cantidad de variables
# - Nombre de variables
# - Cantidad de registros con valores **No nulos**
# - Tipo de dato

# %%
dfprop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121220 entries, 0 to 121219
# Data columns (total 25 columns):
# operation                     121220 non-null object
# property_type                 121220 non-null object
# place_name                    121197 non-null object
# place_with_parent_names       121220 non-null object
# country_name                  121220 non-null object
# state_name                    121220 non-null object
# geonames_id                   102503 non-null float64
# lat-lon                       69670 non-null object
# lat                           69670 non-null float64
# lon                           69670 non-null float64
# price                         100810 non-null float64
# currency                      100809 non-null object
# price_aprox_local_currency    100810 non-null float64
# price_aprox_usd               100810 non-null float64
# surface_total_in_m2           81892 non-null float64
# surface_covered_in_m2         101313 non-null float64
# price_usd_per_m2              68617 non-null float64
# price_per_m2                  87658 non-null float64
# floor                         7899 non-null float64
# rooms                         47390 non-null float64
# expenses                      14262 non-null float64
# properati_url                 121220 non-null object
# description                   121218 non-null object
# title                         121220 non-null object
# image_thumbnail               118108 non-null object
# dtypes: float64(13), object(12)
# memory usage: 24.0+ MB

# %% [markdown]
# ## Visualizacion de valores Nan en cada variable
#
# Visualizamos la cantidad de valores Nan para cada variable

# %%
dfprop[dfprop.isnull().any(axis=1)].isna().sum()
# Out:
# operation                          0
# property_type                      0
# place_name                        23
# place_with_parent_names            0
# country_name                       0
# state_name                         0
# geonames_id                    18717
# lat-lon                        51550
# lat                            51550
# lon                            51550
# price                          20410
# currency                       20411
# price_aprox_local_currency     20410
# price_aprox_usd                20410
# surface_total_in_m2            39328
# surface_covered_in_m2          19907
# price_usd_per_m2               52603
# price_per_m2                   33562
# floor                         113321
# rooms                          73830
# expenses                      106958
# properati_url                      0
# description                        2
# title                              0
# image_thumbnail                 3112
# dtype: int64

# %% [markdown]
# ## Limpieza de datos
# ### Eliminacion de inmuebles sin valor analitico
#
# Eliminamos los inmuebles sin precio ni ubicaciones, ya que no tenemos ninguna forma de estimar un precio.
#
# Condicion:
# - price == Nan
# - price_aprox_local_currency == Nan
# - price_aprox_usd == Nan
# - surface_total_in_m2 == Nan
# - surface_covered_in_m2 == Nan
#
#
# Los registros eliminados son 4733

# %%
# Generamos una mascara para encontrar todos los registros bajo esta condicion
dfprop_withoutprice_withoutsurface=((dfprop['price'].isna()==True)\
                                    &(dfprop['price_aprox_local_currency'].isna()==True)\
                                    &(dfprop['price_aprox_usd'].isna()==True)\
                                    &(dfprop['surface_total_in_m2'].isna()==True)\
                                    &(dfprop['surface_covered_in_m2'].isna()==True))

# Instanciamos el Dataframe excluyendo los registros que no cumple con dicha condicion
dfprop=dfprop.loc[~dfprop_withoutprice_withoutsurface]

# %% [markdown]
# Visualizamos la forma para confirmar que se hayan eliminado los registros

# %%
dfprop.shape
# Out:
# (116487, 25)

# %% [markdown]
# ### Separar en un nuevo Dataframe los inmuebles cuya concentracion por provincia sea menor a 30 operaciones

# %% [markdown]
# Dejaremos en un nuevo DataFrame denominado 'dfprop_fewlocations' las propiedades cuya agrupacion por provincia sea menor a 30 por no tener un valor referencial para la estimacion de precios

# %%
#Creamos dataframe con un valor booleano que indica si la provincia tiene menos de 30 propiedades (True) o no (False).
dfprop_stateless30locations=dfprop.groupby('state_name')[['operation']].count()<30

# Renombramos la columna  
dfprop_stateless30locations.rename(columns={'state_name':'state_name','operation':'less_30_locations'},inplace=True)

# Hacemos un merge con dfprop para marcar cada una de las propiedades
dfprop=pd.merge(dfprop,dfprop_stateless30locations,how='left',on='state_name')
    
# Generamos un nuevo Dataframe para almacenar las propiedades correspondientes a provincias con menos de 30 propiedades
dfprop_fewlocations=dfprop.loc[dfprop['less_30_locations']==True]

# Eliminamos del dataframe proncipal dichas ubiaciones
dfprop=dfprop.loc[dfprop['less_30_locations']==False]

#Eliminamos las columnas de ambos dataframes
dfprop_fewlocations.drop(['less_30_locations'],axis=1,inplace=True)
dfprop.drop(['less_30_locations'],axis=1,inplace=True)

#Verificamos la cantidad de ubicaciones dentro del dataframe auxiliar
dfprop_fewlocations.shape
# Out:
# (74, 25)

# %%
#Corroboramos que se hayan eliminado las propiedades del dataframe principal
dfprop.shape
# Out:
# (116413, 25)

# %% [markdown]
# Eliminamos propiedad en moneda distinta a ARS o USD (se excluye 'NaN' siendo que tendran tratamiento mas adelante)

# %%
dfprop['currency'].unique()
# Out:
# array(['USD', nan, 'ARS', 'PEN', 'UYU'], dtype=object)

# %%
dfprop=dfprop.loc[((dfprop['currency']!='UYU')&(dfprop['currency']!='PEN'))]

#Corroboramos que se hayan eliminado las propiedades del dataframe principal
dfprop['currency'].unique()
# Out:
# array(['USD', nan, 'ARS'], dtype=object)

# %% [markdown]
# Eliminamos la categoria 'store', siendo que nuestro analisis será para viviendas de ocupacion permanente.

# %%
dfprop['property_type'].unique()
# Out:
# array(['PH', 'apartment', 'house', 'store'], dtype=object)

# %%
dfprop=dfprop.loc[(dfprop['property_type']!='store')]

# %%
dfprop['property_type'].unique()
# Out:
# array(['PH', 'apartment', 'house'], dtype=object)

# %% [markdown]
# # Imputacion
# ## Variable place_name - valores Nan:
# - Analizamos los valores NaN de la columna 'place_name':

# %%
dfprop.loc[(dfprop['place_name'].isna() == True),['place_name','place_with_parent_names']]
# Out:
#       place_name                      place_with_parent_names
# 6201         NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 9686         NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 10855        NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 14066        NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 17672        NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 20765        NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 22398        NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 23404        NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 36842        NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 43577        NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 44227        NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 50404        NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 52495        NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 54729        NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 54784        NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 54788        NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 54816        NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 55003        NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 55036        NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 55996        NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 59189        NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 59191        NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||
# 60539        NaN  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||

# %% [markdown]
# - Vemos que, de acuerdo a 'place_name_with_parents', todos los valores faltantes son 'Tigre'.
# - Por lo tanto, procedemos a reemplazarlos:

# %%
dfprop['place_name'].fillna( value = 'Tigre', inplace = True)

# %% [markdown]
# Volvemos a visualizar la cantidad de valores nulos para confirmar que no haya mas valores **Nan** en la variable 'place_name'

# %%
dfprop[dfprop.isnull().any(axis=1)].isna().sum()
# Out:
# operation                          0
# property_type                      0
# place_name                         0
# place_with_parent_names            0
# country_name                       0
# state_name                         0
# geonames_id                    17992
# lat-lon                        48544
# lat                            48544
# lon                            48544
# price                          14973
# currency                       14974
# price_aprox_local_currency     14973
# price_aprox_usd                14973
# surface_total_in_m2            33301
# surface_covered_in_m2          14356
# price_usd_per_m2               45984
# price_per_m2                   27407
# floor                         104901
# rooms                          67543
# expenses                       98647
# properati_url                      0
# description                        2
# title                              0
# image_thumbnail                 2666
# dtype: int64

# %% [markdown]
# ## Variables 'surface_total_in_m2' y 'surface_covered_in_m2' - valores Nan
# Analizamos los valores que tienen 'surface_covered_in_m2', pero no 'surface_total_in_m2'

# %%
dfprop.isnull().sum()
# Out:
# operation                          0
# property_type                      0
# place_name                         0
# place_with_parent_names            0
# country_name                       0
# state_name                         0
# geonames_id                    17992
# lat-lon                        48544
# lat                            48544
# lon                            48544
# price                          14973
# currency                       14974
# price_aprox_local_currency     14973
# price_aprox_usd                14973
# surface_total_in_m2            33301
# surface_covered_in_m2          14356
# price_usd_per_m2               45984
# price_per_m2                   27407
# floor                         104901
# rooms                          67543
# expenses                       98647
# properati_url                      0
# description                        2
# title                              0
# image_thumbnail                 2666
# dtype: int64

# %%
dfprop_surfaceanalysis = dfprop[(dfprop['surface_total_in_m2'].isna() == True) & (dfprop['surface_covered_in_m2'].isna() == False)]
dfprop_surfaceanalysis[['surface_total_in_m2', 'surface_covered_in_m2']].sample(10)
# Out:
#        surface_total_in_m2  surface_covered_in_m2
# 34076                  NaN                   24.0
# 10806                  NaN                   20.0
# 35546                  NaN                   65.0
# 18680                  NaN                   24.0
# 78580                  NaN                  315.0
# 73942                  NaN                   37.0
# 59533                  NaN                  180.0
# 41806                  NaN                   43.0
# 924                    NaN                  140.0
# 42610                  NaN                  120.0

# %% [markdown]
# Reemplazamos los valores NaN de la columna 'surface_total_in_m2', asumiendo que en estos casos es igual al valor de 'surface_covered_in_m2'

# %%
dfprop.fillna({'surface_total_in_m2' : dfprop['surface_covered_in_m2']}, inplace = True)

# %% [markdown]
# Volvemos a constatar la cantidad de valores nulos en el dataframe:

# %%
dfprop.isnull().sum()
# Out:
# operation                          0
# property_type                      0
# place_name                         0
# place_with_parent_names            0
# country_name                       0
# state_name                         0
# geonames_id                    17992
# lat-lon                        48544
# lat                            48544
# lon                            48544
# price                          14973
# currency                       14974
# price_aprox_local_currency     14973
# price_aprox_usd                14973
# surface_total_in_m2             7283
# surface_covered_in_m2          14356
# price_usd_per_m2               45984
# price_per_m2                   27407
# floor                         104901
# rooms                          67543
# expenses                       98647
# properati_url                      0
# description                        2
# title                              0
# image_thumbnail                 2666
# dtype: int64

# %% [markdown]
# Repetimos la operación para los casos en los que no tenemos valor de 'surface_covered_in_m2', completando con el valor de 'surface_total_in_m2':

# %%
dfprop_surfaceanalysis = dfprop[(dfprop['surface_covered_in_m2'].isna() == True) & (dfprop['surface_total_in_m2'].isna() == False)]
dfprop_surfaceanalysis[['surface_total_in_m2', 'surface_covered_in_m2']].sample(10)
# Out:
#         surface_total_in_m2  surface_covered_in_m2
# 34121                 360.0                    NaN
# 115457                  0.0                    NaN
# 99338                 550.0                    NaN
# 68103                  50.0                    NaN
# 102731                 40.0                    NaN
# 19859                 629.0                    NaN
# 50539                  52.0                    NaN
# 59711                  48.0                    NaN
# 99522                  76.0                    NaN
# 31458                  42.0                    NaN

# %%
dfprop.fillna({'surface_covered_in_m2' : dfprop['surface_total_in_m2']}, inplace = True)

# %%
dfprop.isnull().sum()
# Out:
# operation                          0
# property_type                      0
# place_name                         0
# place_with_parent_names            0
# country_name                       0
# state_name                         0
# geonames_id                    17992
# lat-lon                        48544
# lat                            48544
# lon                            48544
# price                          14973
# currency                       14974
# price_aprox_local_currency     14973
# price_aprox_usd                14973
# surface_total_in_m2             7283
# surface_covered_in_m2           7283
# price_usd_per_m2               45984
# price_per_m2                   27407
# floor                         104901
# rooms                          67543
# expenses                       98647
# properati_url                      0
# description                        2
# title                              0
# image_thumbnail                 2666
# dtype: int64

# %% [markdown]
# Imputamos la variable 'price_per_m2' calculandola en base a 'price_aprox_us' y 'surface_total_in_m2'

# %%
dfprop.loc[dfprop['price_usd_per_m2'].isna() &\
           (~dfprop['price_aprox_usd'].isna())&\
            (~dfprop['surface_total_in_m2'].isna())&\
            (dfprop['surface_total_in_m2']!=0.),\
           'price_usd_per_m2']= dfprop['price_aprox_usd']/dfprop['surface_total_in_m2']

# %%
dfprop.isnull().sum()
# Out:
# operation                          0
# property_type                      0
# place_name                         0
# place_with_parent_names            0
# country_name                       0
# state_name                         0
# geonames_id                    17992
# lat-lon                        48544
# lat                            48544
# lon                            48544
# price                          14973
# currency                       14974
# price_aprox_local_currency     14973
# price_aprox_usd                14973
# surface_total_in_m2             7283
# surface_covered_in_m2           7283
# price_usd_per_m2               22497
# price_per_m2                   27407
# floor                         104901
# rooms                          67543
# expenses                       98647
# properati_url                      0
# description                        2
# title                              0
# image_thumbnail                 2666
# dtype: int64

# %%
dfprop.shape
# Out:
# (112458, 25)

# %% [markdown]
# Eliminamos propiedades sin precio y con cantidad de metro=0

# %%
dfprop=dfprop.drop(dfprop.loc[(dfprop['price_usd_per_m2'].isna())&
                                 (dfprop['price'].isna())&
                                 (dfprop['surface_total_in_m2']==0)].index)

dfprop.shape
# Out:
# (112327, 25)

# %% [markdown]
# ### Variable  'state_name' vs 'place_with_parent_names'
# Notamos que la columna **'place_name'** contiene valores no que aportan una clara referencia de la ubicacion geografica del inmueble.
#
# Por ejemplo
# - place_name: 'Centro'
# - place_with_parent_names: '|Argentina|Buenos Aires Costa Atlántica|Mar del Plata|Centro|'
#
# Adicionalmente, los valores contenidos por esta columna no tienen el mismo valor referencial, lo cual difculta entender la precision de dicha columna.
#
# Por ello utilizamos **'place_with_parent_names'** que nos permite definir correctamente la ubicacion geografica del inmueble.
#
# Por lo tanto, separamos el texto y generaremos una nueva columna quedando el dataset con esta estructura.
#
# - country_name: Pais
# - state_name: provincia (salvo buenos aires que indicara la zona)
# - district_name: localidad o partido
# - city_name: barrio

# %%
# Split por el caracter "|"
dfplacename=[sublista.split('|') for sublista in dfprop['place_with_parent_names']]

# De cada una de las listas quitamos el ultimo y el primer caracter, ya que son vacios
# ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Vicente López', 'Munro', '']
dfplacename=[sublista[1:5] for sublista in dfplacename]


# Se extrae el nombre de distrito o localidad en una nueva variable denominada 'district_name'
dfprop['district_name']=[str.strip(sublista[2]) if str.strip(sublista[2])!='' else np.nan for sublista in dfplacename]


# Se extrae el nombre de la ciudad o barrio en una nueva variable denominada 'city_name'
dfprop['city_name']=[str.strip(sublista[3]) if (len(sublista)>3  and sublista[3]) else np.nan for sublista in dfplacename]

# Finalmente columnas a ser utilizada seran:
# 'country_name'
# 'state_name'
# 'district_name'
#  'city_name'
# A partir de esas hacer las imputaciones

dfprop[['country_name','state_name','district_name','city_name']].sample(10)
# Out:
#        country_name                state_name      district_name    city_name
# 51631     Argentina  Bs.As. G.B.A. Zona Norte              Pilar          NaN
# 100702    Argentina    Bs.As. G.B.A. Zona Sur    Almirante Brown  Jose Marmol
# 100121    Argentina                  Santa Fe            Rosario          NaN
# 51076     Argentina                  Misiones            Posadas          NaN
# 24306     Argentina           Capital Federal      San Cristobal          NaN
# 90598     Argentina                   Córdoba            Córdoba          NaN
# 13782     Argentina  Bs.As. G.B.A. Zona Oeste         La Matanza   La Tablada
# 93218     Argentina                  Santa Fe            Rosario          NaN
# 75375     Argentina                  Santa Fe            Rosario          NaN
# 92152     Argentina  Bs.As. G.B.A. Zona Oeste  General Rodríguez  La Cesarina

# %% [markdown]
# ### Eliminamos inmuebles sin nombre del distrito

# %% [markdown]
# Quitamos casos sin district_name ya que no nos permiten brindar un valor de referencia debido a que no tienen una zona claramente indicada

# %%
mask_nodistrict_nocity_silatlon=(dfprop['district_name'].isna()==True)
dfprop=dfprop.loc[~mask_nodistrict_nocity_silatlon]
dfprop.shape
# Out:
# (108003, 27)

# %% [markdown]
# ### Eliminamos las propiedades que por 'district_name' no lleguen a 30 operaciones

# %%
dfprop.groupby(by=['district_name']).count()
# Out:
#                            operation  property_type  place_name  \
# district_name
# Abasto                           103            103         103
# Achiras                            7              7           7
# Adolfo Alsina                      8              8           8
# Agronomía                         39             39          39
# Agua de Oro                        6              6           6
# Aguas Verdes                      15             15          15
# Aldea Brasilera                    1              1           1
# Alejandro Roca                     1              1           1
# Almafuerte                         7              7           7
# Almagro                         1120           1120        1120
# Almirante Brown                 1520           1520        1520
# Alta Gracia                       18             18          18
# Alvear                             2              2           2
# Anisacate                          7              7           7
# Apóstoles                          1              1           1
# Arequito                           1              1           1
# Arocena                            3              3           3
# Arroyo Ceibal                      1              1           1
# Arroyo Seco                        2              2           2
# Ascochinga                         7              7           7
# Avellaneda                       628            628         628
# Azara                              1              1           1
# Azul                              17             17          17
# Bahía Blanca                     456            456         456
# Balcarce                          80             80          80
# Balnearia                          1              1           1
# Balvanera                        626            626         626
# Banda del Río Salí                 1              1           1
# Baradero                           6              6           6
# Barracas                         410            410         410
# ...                              ...            ...         ...
# Villa Larca                        1              1           1
# Villa Llao Llao                    1              1           1
# Villa Los Aromos                   1              1           1
# Villa Lugano                     199            199         199
# Villa Luro                       411            411         411
# Villa María                        9              9           9
# Villa Mercedes                     7              7           7
# Villa Nueva                        4              4           4
# Villa Ortuzar                     78             78          78
# Villa Paranacito                   1              1           1
# Villa Parque Santa Ana             3              3           3
# Villa Parque Siquiman              6              6           6
# Villa Pueyrredón                 175            175         175
# Villa Real                        36             36          36
# Villa Riachuelo                    6              6           6
# Villa Rumipal                     13             13          13
# Villa Santa Cruz del Lago         11             11          11
# Villa Santa Rita                  55             55          55
# Villa Soldati                     13             13          13
# Villa Urquiza                   1607           1607        1607
# Villa de Las Rosas                 3              3           3
# Villa de Soto                      2              2           2
# Villa del Dique                   20             20          20
# Villa del Parque                 469            469         469
# Villa del Totoral                  8              8           8
# Villarino                          1              1           1
# Vistalba                           1              1           1
# Wenceslao Escalante                1              1           1
# Yerba Buena                      161            161         161
# Zárate                            15             15          15
#
#                            place_with_parent_names  country_name  state_name  \
# district_name
# Abasto                                         103           103         103
# Achiras                                          7             7           7
# Adolfo Alsina                                    8             8           8
# Agronomía                                       39            39          39
# Agua de Oro                                      6             6           6
# Aguas Verdes                                    15            15          15
# Aldea Brasilera                                  1             1           1
# Alejandro Roca                                   1             1           1
# Almafuerte                                       7             7           7
# Almagro                                       1120          1120        1120
# Almirante Brown                               1520          1520        1520
# Alta Gracia                                     18            18          18
# Alvear                                           2             2           2
# Anisacate                                        7             7           7
# Apóstoles                                        1             1           1
# Arequito                                         1             1           1
# Arocena                                          3             3           3
# Arroyo Ceibal                                    1             1           1
# Arroyo Seco                                      2             2           2
# Ascochinga                                       7             7           7
# Avellaneda                                     628           628         628
# Azara                                            1             1           1
# Azul                                            17            17          17
# Bahía Blanca                                   456           456         456
# Balcarce                                        80            80          80
# Balnearia                                        1             1           1
# Balvanera                                      626           626         626
# Banda del Río Salí                               1             1           1
# Baradero                                         6             6           6
# Barracas                                       410           410         410
# ...                                            ...           ...         ...
# Villa Larca                                      1             1           1
# Villa Llao Llao                                  1             1           1
# Villa Los Aromos                                 1             1           1
# Villa Lugano                                   199           199         199
# Villa Luro                                     411           411         411
# Villa María                                      9             9           9
# Villa Mercedes                                   7             7           7
# Villa Nueva                                      4             4           4
# Villa Ortuzar                                   78            78          78
# Villa Paranacito                                 1             1           1
# Villa Parque Santa Ana                           3             3           3
# Villa Parque Siquiman                            6             6           6
# Villa Pueyrredón                               175           175         175
# Villa Real                                      36            36          36
# Villa Riachuelo                                  6             6           6
# Villa Rumipal                                   13            13          13
# Villa Santa Cruz del Lago                       11            11          11
# Villa Santa Rita                                55            55          55
# Villa Soldati                                   13            13          13
# Villa Urquiza                                 1607          1607        1607
# Villa de Las Rosas                               3             3           3
# Villa de Soto                                    2             2           2
# Villa del Dique                                 20            20          20
# Villa del Parque                               469           469         469
# Villa del Totoral                                8             8           8
# Villarino                                        1             1           1
# Vistalba                                         1             1           1
# Wenceslao Escalante                              1             1           1
# Yerba Buena                                    161           161         161
# Zárate                                          15            15          15
#
#                            geonames_id  lat-lon   lat   lon  ...  \
# district_name                                                ...
# Abasto                               0       68    68    68  ...
# Achiras                              7        7     7     7  ...
# Adolfo Alsina                        8        3     3     3  ...
# Agronomía                           39       39    39    39  ...
# Agua de Oro                          6        2     2     2  ...
# Aguas Verdes                        15       15    15    15  ...
# Aldea Brasilera                      1        1     1     1  ...
# Alejandro Roca                       0        0     0     0  ...
# Almafuerte                           7        3     3     3  ...
# Almagro                           1120      920   920   920  ...
# Almirante Brown                    813      527   527   527  ...
# Alta Gracia                         18       11    11    11  ...
# Alvear                               2        2     2     2  ...
# Anisacate                            7        3     3     3  ...
# Apóstoles                            1        1     1     1  ...
# Arequito                             1        1     1     1  ...
# Arocena                              3        3     3     3  ...
# Arroyo Ceibal                        0        0     0     0  ...
# Arroyo Seco                          2        2     2     2  ...
# Ascochinga                           7        2     2     2  ...
# Avellaneda                         615      396   396   396  ...
# Azara                                1        1     1     1  ...
# Azul                                15       14    14    14  ...
# Bahía Blanca                       456      436   436   436  ...
# Balcarce                            80       76    76    76  ...
# Balnearia                            1        1     1     1  ...
# Balvanera                          626      558   558   558  ...
# Banda del Río Salí                   1        1     1     1  ...
# Baradero                             6        5     5     5  ...
# Barracas                           410      357   357   357  ...
# ...                                ...      ...   ...   ...  ...
# Villa Larca                          1        0     0     0  ...
# Villa Llao Llao                      0        1     1     1  ...
# Villa Los Aromos                     0        1     1     1  ...
# Villa Lugano                       199      162   162   162  ...
# Villa Luro                         411      343   343   343  ...
# Villa María                          9        2     2     2  ...
# Villa Mercedes                       0        5     5     5  ...
# Villa Nueva                          4        2     2     2  ...
# Villa Ortuzar                       78       65    65    65  ...
# Villa Paranacito                     1        0     0     0  ...
# Villa Parque Santa Ana               0        3     3     3  ...
# Villa Parque Siquiman                0        3     3     3  ...
# Villa Pueyrredón                   175      137   137   137  ...
# Villa Real                          36       35    35    35  ...
# Villa Riachuelo                      6        6     6     6  ...
# Villa Rumipal                       13        8     8     8  ...
# Villa Santa Cruz del Lago            0       10    10    10  ...
# Villa Santa Rita                    55       54    54    54  ...
# Villa Soldati                       13       13    13    13  ...
# Villa Urquiza                     1607     1068  1068  1068  ...
# Villa de Las Rosas                   3        3     3     3  ...
# Villa de Soto                        2        2     2     2  ...
# Villa del Dique                     20        9     9     9  ...
# Villa del Parque                   469      312   312   312  ...
# Villa del Totoral                    8        4     4     4  ...
# Villarino                            1        1     1     1  ...
# Vistalba                             1        1     1     1  ...
# Wenceslao Escalante                  1        1     1     1  ...
# Yerba Buena                        161       34    34    34  ...
# Zárate                               8        8     8     8  ...
#
#                            price_usd_per_m2  price_per_m2  floor  rooms  \
# district_name
# Abasto                                   92            88     17     61
# Achiras                                   1             1      1      7
# Adolfo Alsina                             0             0      0      8
# Agronomía                                36            35      2     32
# Agua de Oro                               3             3      0      1
# Aguas Verdes                              6             6      1     14
# Aldea Brasilera                           1             1      0      1
# Alejandro Roca                            1             1      0      1
# Almafuerte                                1             1      0      5
# Almagro                                 941           921    149    706
# Almirante Brown                        1070           999      7    156
# Alta Gracia                              10            10      2      6
# Alvear                                    2             1      0      1
# Anisacate                                 6             6      0      3
# Apóstoles                                 1             1      0      1
# Arequito                                  1             1      0      1
# Arocena                                   0             0      0      0
# Arroyo Ceibal                             1             1      0      1
# Arroyo Seco                               1             1      0      1
# Ascochinga                                3             3      1      4
# Avellaneda                              581           547     28    292
# Azara                                     1             1      0      1
# Azul                                     13            12      1      4
# Bahía Blanca                            351           311      0    269
# Balcarce                                 37            32      0     71
# Balnearia                                 0             0      0      1
# Balvanera                               588           559    141    428
# Banda del Río Salí                        0             0      0      1
# Baradero                                  6             6      0      3
# Barracas                                380           361     26    235
# ...                                     ...           ...    ...    ...
# Villa Larca                               1             1      0      0
# Villa Llao Llao                           1             1      0      0
# Villa Los Aromos                          1             1      0      0
# Villa Lugano                            179           168     16    114
# Villa Luro                              352           316     24    143
# Villa María                               6             6      0      2
# Villa Mercedes                            0             0      1      7
# Villa Nueva                               1             1      0      4
# Villa Ortuzar                            77            76      2     38
# Villa Paranacito                          1             1      0      0
# Villa Parque Santa Ana                    3             3      0      3
# Villa Parque Siquiman                     1             1      0      2
# Villa Pueyrredón                        169           164      6     88
# Villa Real                               36            36      0     17
# Villa Riachuelo                           5             5      1      3
# Villa Rumipal                             7             7      0      6
# Villa Santa Cruz del Lago                10            10      0      6
# Villa Santa Rita                         54            54     11     39
# Villa Soldati                            13            13      3     12
# Villa Urquiza                          1333          1308    116    554
# Villa de Las Rosas                        3             3      0      3
# Villa de Soto                             2             2      0      0
# Villa del Dique                          12            11      0      8
# Villa del Parque                        436           430     34    177
# Villa del Totoral                         6             6      0      0
# Villarino                                 0             0      0      0
# Vistalba                                  0             0      0      1
# Wenceslao Escalante                       1             0      0      0
# Yerba Buena                              20            12      0     18
# Zárate                                   12            12      1      7
#
#                            expenses  properati_url  description  title  \
# district_name
# Abasto                           26            103          103    103
# Achiras                           0              7            7      7
# Adolfo Alsina                     0              8            8      8
# Agronomía                         8             39           39     39
# Agua de Oro                       0              6            6      6
# Aguas Verdes                      0             15           15     15
# Aldea Brasilera                   0              1            1      1
# Alejandro Roca                    0              1            1      1
# Almafuerte                        0              7            7      7
# Almagro                         284           1120         1120   1120
# Almirante Brown                  93           1520         1520   1520
# Alta Gracia                       0             18           18     18
# Alvear                            0              2            2      2
# Anisacate                         0              7            7      7
# Apóstoles                         0              1            1      1
# Arequito                          0              1            1      1
# Arocena                           0              3            3      3
# Arroyo Ceibal                     0              1            1      1
# Arroyo Seco                       0              2            2      2
# Ascochinga                        0              7            7      7
# Avellaneda                       62            628          628    628
# Azara                             0              1            1      1
# Azul                              1             17           17     17
# Bahía Blanca                     10            456          456    456
# Balcarce                          1             80           80     80
# Balnearia                         0              1            1      1
# Balvanera                       191            626          626    626
# Banda del Río Salí                0              1            1      1
# Baradero                          1              6            6      6
# Barracas                         56            410          410    410
# ...                             ...            ...          ...    ...
# Villa Larca                       0              1            1      1
# Villa Llao Llao                   0              1            1      1
# Villa Los Aromos                  0              1            1      1
# Villa Lugano                     16            199          199    199
# Villa Luro                       47            411          411    411
# Villa María                       1              9            9      9
# Villa Mercedes                    0              7            7      7
# Villa Nueva                       0              4            4      4
# Villa Ortuzar                    23             78           78     78
# Villa Paranacito                  0              1            1      1
# Villa Parque Santa Ana            0              3            3      3
# Villa Parque Siquiman             0              6            6      6
# Villa Pueyrredón                 22            175          175    175
# Villa Real                        2             36           36     36
# Villa Riachuelo                   0              6            6      6
# Villa Rumipal                     0             13           13     13
# Villa Santa Cruz del Lago         0             11           11     11
# Villa Santa Rita                  2             55           55     55
# Villa Soldati                     0             13           13     13
# Villa Urquiza                   184           1607         1607   1607
# Villa de Las Rosas                0              3            3      3
# Villa de Soto                     0              2            2      2
# Villa del Dique                   0             20           20     20
# Villa del Parque                 91            469          469    469
# Villa del Totoral                 0              8            8      8
# Villarino                         0              1            1      1
# Vistalba                          0              1            1      1
# Wenceslao Escalante               0              1            1      1
# Yerba Buena                      22            161          161    161
# Zárate                            0             15           15     15
#
#                            image_thumbnail  city_name
# district_name
# Abasto                                  97          0
# Achiras                                  7          0
# Adolfo Alsina                            8          0
# Agronomía                               39          0
# Agua de Oro                              6          0
# Aguas Verdes                            15          0
# Aldea Brasilera                          1          0
# Alejandro Roca                           0          0
# Almafuerte                               7          0
# Almagro                               1119          0
# Almirante Brown                       1454       1481
# Alta Gracia                             16          0
# Alvear                                   2          0
# Anisacate                                7          0
# Apóstoles                                1          0
# Arequito                                 1          0
# Arocena                                  3          0
# Arroyo Ceibal                            1          0
# Arroyo Seco                              2          0
# Ascochinga                               7          0
# Avellaneda                             627        404
# Azara                                    1          0
# Azul                                    15          2
# Bahía Blanca                           454          5
# Balcarce                                80          1
# Balnearia                                1          0
# Balvanera                              624          0
# Banda del Río Salí                       1          0
# Baradero                                 6          0
# Barracas                               410          0
# ...                                    ...        ...
# Villa Larca                              1          0
# Villa Llao Llao                          1          0
# Villa Los Aromos                         1          0
# Villa Lugano                           197          0
# Villa Luro                             411          0
# Villa María                              9          0
# Villa Mercedes                           7          0
# Villa Nueva                              4          0
# Villa Ortuzar                           78          0
# Villa Paranacito                         1          0
# Villa Parque Santa Ana                   3          0
# Villa Parque Siquiman                    6          0
# Villa Pueyrredón                       174          0
# Villa Real                              36          0
# Villa Riachuelo                          6          0
# Villa Rumipal                           13          0
# Villa Santa Cruz del Lago               11          0
# Villa Santa Rita                        55          0
# Villa Soldati                           13          0
# Villa Urquiza                         1571          0
# Villa de Las Rosas                       3          0
# Villa de Soto                            2          0
# Villa del Dique                         18          0
# Villa del Parque                       467          0
# Villa del Totoral                        8          0
# Villarino                                1          1
# Vistalba                                 1          0
# Wenceslao Escalante                      1          0
# Yerba Buena                            155          0
# Zárate                                  14          8
#
# [481 rows x 26 columns]

# %%
#Creamos dataframe con un valor booleano que indica si district tiene menos de 30 propiedades (True) o no (False).
dfprop_districtless30locations=dfprop.groupby('district_name')[['operation']].count()<30

# Renombramos la columna  
dfprop_districtless30locations.rename(columns={'district_name':'district_name','operation':'less_30_locations'},inplace=True)

# Hacemos un merge con dfprop para marcar cada una de las propiedades
dfprop=pd.merge(dfprop,dfprop_districtless30locations,how='left',on='district_name')
    
# Generamos un nuevo Dataframe para almacenar las propiedades correspondientes a district con menos de 30 propiedades
dfprop_fewlocations=dfprop.loc[dfprop['less_30_locations']==True]

# Eliminamos del dataframe proncipal dichas ubiaciones
dfprop=dfprop.loc[dfprop['less_30_locations']==False]

#Eliminamos las columnas de ambos dataframes
dfprop_fewlocations.drop(['less_30_locations'],axis=1,inplace=True)
dfprop.drop(['less_30_locations'],axis=1,inplace=True)

#Verificamos la cantidad de ubicaciones dentro del dataframe auxiliar
dfprop_fewlocations.shape
# Out:
# (1895, 27)

# %%
dfprop.groupby(by=['district_name']).count()
# Out:
#                         operation  property_type  place_name  \
# district_name
# Abasto                        103            103         103
# Agronomía                      39             39          39
# Almagro                      1120           1120        1120
# Almirante Brown              1520           1520        1520
# Avellaneda                    628            628         628
# Bahía Blanca                  456            456         456
# Balcarce                       80             80          80
# Balvanera                     626            626         626
# Barracas                      410            410         410
# Barrio Norte                 1078           1078        1078
# Belgrano                     2917           2917        2917
# Berazategui                   450            450         450
# Boca                          216            216         216
# Boedo                         867            867         867
# Caballito                    2225           2225        2225
# Capitán Bermúdez               47             47          47
# Cariló                         55             55          55
# Cañuelas                       45             45          45
# Centro / Microcentro          159            159         159
# Chacarita                     219            219         219
# Chascomús                      55             55          55
# Coghlan                       253            253         253
# Colegiales                    342            342         342
# Colón                          98             98          98
# Confluencia                   113            113         113
# Congreso                      284            284         284
# Constitución                  199            199         199
# Coronel Suárez                 73             73          73
# Costa Esmeralda               125            125         125
# Cushamen                       71             71          71
# ...                           ...            ...         ...
# Santa Teresita                 46             46          46
# Santo Tomé                     44             44          44
# Tandil                         73             73          73
# Tigre                        8914           8914        8914
# Trenque Lauquen                40             40          40
# Tres Arroyos                   79             79          79
# Tres de Febrero              1256           1256        1256
# Tribunales                     71             71          71
# Unquillo                       32             32          32
# Valeria del Mar                53             53          53
# Velez Sarsfield                37             37          37
# Versalles                      55             55          55
# Vicente López                3555           3555        3555
# Villa Allende                 196            196         196
# Villa Carlos Paz              573            573         573
# Villa Crespo                 1243           1243        1243
# Villa Devoto                  389            389         389
# Villa General Belgrano         79             79          79
# Villa General Mitre            48             48          48
# Villa Gesell                  292            292         292
# Villa La Angostura            132            132         132
# Villa Lugano                  199            199         199
# Villa Luro                    411            411         411
# Villa Ortuzar                  78             78          78
# Villa Pueyrredón              175            175         175
# Villa Real                     36             36          36
# Villa Santa Rita               55             55          55
# Villa Urquiza                1607           1607        1607
# Villa del Parque              469            469         469
# Yerba Buena                   161            161         161
#
#                         place_with_parent_names  country_name  state_name  \
# district_name
# Abasto                                      103           103         103
# Agronomía                                    39            39          39
# Almagro                                    1120          1120        1120
# Almirante Brown                            1520          1520        1520
# Avellaneda                                  628           628         628
# Bahía Blanca                                456           456         456
# Balcarce                                     80            80          80
# Balvanera                                   626           626         626
# Barracas                                    410           410         410
# Barrio Norte                               1078          1078        1078
# Belgrano                                   2917          2917        2917
# Berazategui                                 450           450         450
# Boca                                        216           216         216
# Boedo                                       867           867         867
# Caballito                                  2225          2225        2225
# Capitán Bermúdez                             47            47          47
# Cariló                                       55            55          55
# Cañuelas                                     45            45          45
# Centro / Microcentro                        159           159         159
# Chacarita                                   219           219         219
# Chascomús                                    55            55          55
# Coghlan                                     253           253         253
# Colegiales                                  342           342         342
# Colón                                        98            98          98
# Confluencia                                 113           113         113
# Congreso                                    284           284         284
# Constitución                                199           199         199
# Coronel Suárez                               73            73          73
# Costa Esmeralda                             125           125         125
# Cushamen                                     71            71          71
# ...                                         ...           ...         ...
# Santa Teresita                               46            46          46
# Santo Tomé                                   44            44          44
# Tandil                                       73            73          73
# Tigre                                      8914          8914        8914
# Trenque Lauquen                              40            40          40
# Tres Arroyos                                 79            79          79
# Tres de Febrero                            1256          1256        1256
# Tribunales                                   71            71          71
# Unquillo                                     32            32          32
# Valeria del Mar                              53            53          53
# Velez Sarsfield                              37            37          37
# Versalles                                    55            55          55
# Vicente López                              3555          3555        3555
# Villa Allende                               196           196         196
# Villa Carlos Paz                            573           573         573
# Villa Crespo                               1243          1243        1243
# Villa Devoto                                389           389         389
# Villa General Belgrano                       79            79          79
# Villa General Mitre                          48            48          48
# Villa Gesell                                292           292         292
# Villa La Angostura                          132           132         132
# Villa Lugano                                199           199         199
# Villa Luro                                  411           411         411
# Villa Ortuzar                                78            78          78
# Villa Pueyrredón                            175           175         175
# Villa Real                                   36            36          36
# Villa Santa Rita                             55            55          55
# Villa Urquiza                              1607          1607        1607
# Villa del Parque                            469           469         469
# Yerba Buena                                 161           161         161
#
#                         geonames_id  lat-lon   lat   lon  ...  \
# district_name                                             ...
# Abasto                            0       68    68    68  ...
# Agronomía                        39       39    39    39  ...
# Almagro                        1120      920   920   920  ...
# Almirante Brown                 813      527   527   527  ...
# Avellaneda                      615      396   396   396  ...
# Bahía Blanca                    456      436   436   436  ...
# Balcarce                         80       76    76    76  ...
# Balvanera                       626      558   558   558  ...
# Barracas                        410      357   357   357  ...
# Barrio Norte                   1078      860   860   860  ...
# Belgrano                       2917     1914  1914  1914  ...
# Berazategui                     253      380   380   380  ...
# Boca                            216      127   127   127  ...
# Boedo                           867      321   321   321  ...
# Caballito                      2225     1784  1784  1784  ...
# Capitán Bermúdez                 47       47    47    47  ...
# Cariló                            0       41    41    41  ...
# Cañuelas                         42       31    31    31  ...
# Centro / Microcentro            159      157   157   157  ...
# Chacarita                       219      153   153   153  ...
# Chascomús                         6       42    42    42  ...
# Coghlan                         253      214   214   214  ...
# Colegiales                      342      308   308   308  ...
# Colón                            98       32    32    32  ...
# Confluencia                     113       53    53    53  ...
# Congreso                        284      221   221   221  ...
# Constitución                    199      185   185   185  ...
# Coronel Suárez                   73       57    57    57  ...
# Costa Esmeralda                   0       98    98    98  ...
# Cushamen                         71        0     0     0  ...
# ...                             ...      ...   ...   ...  ...
# Santa Teresita                   46       28    28    28  ...
# Santo Tomé                       44       39    39    39  ...
# Tandil                           73       66    66    66  ...
# Tigre                          3123     4415  4415  4415  ...
# Trenque Lauquen                  40       37    37    37  ...
# Tres Arroyos                     79       73    73    73  ...
# Tres de Febrero                1084     1055  1055  1055  ...
# Tribunales                        0       62    62    62  ...
# Unquillo                         32       12    12    12  ...
# Valeria del Mar                  53       43    43    43  ...
# Velez Sarsfield                  37       35    35    35  ...
# Versalles                        55       55    55    55  ...
# Vicente López                  2884     1233  1233  1233  ...
# Villa Allende                   196       83    83    83  ...
# Villa Carlos Paz                573      498   498   498  ...
# Villa Crespo                   1243      861   861   861  ...
# Villa Devoto                    389      363   363   363  ...
# Villa General Belgrano           79       62    62    62  ...
# Villa General Mitre              48       48    48    48  ...
# Villa Gesell                    292      269   269   269  ...
# Villa La Angostura              132       36    36    36  ...
# Villa Lugano                    199      162   162   162  ...
# Villa Luro                      411      343   343   343  ...
# Villa Ortuzar                    78       65    65    65  ...
# Villa Pueyrredón                175      137   137   137  ...
# Villa Real                       36       35    35    35  ...
# Villa Santa Rita                 55       54    54    54  ...
# Villa Urquiza                  1607     1068  1068  1068  ...
# Villa del Parque                469      312   312   312  ...
# Yerba Buena                     161       34    34    34  ...
#
#                         price_usd_per_m2  price_per_m2  floor  rooms  \
# district_name
# Abasto                                92            88     17     61
# Agronomía                             36            35      2     32
# Almagro                              941           921    149    706
# Almirante Brown                     1070           999      7    156
# Avellaneda                           581           547     28    292
# Bahía Blanca                         351           311      0    269
# Balcarce                              37            32      0     71
# Balvanera                            588           559    141    428
# Barracas                             380           361     26    235
# Barrio Norte                         955           910    100    641
# Belgrano                            2468          2362    189   1141
# Berazategui                          353           345      7    192
# Boca                                 201           192     16     87
# Boedo                                829           824     19    744
# Caballito                           2000          1969    331   1127
# Capitán Bermúdez                      46            46      0      4
# Cariló                                39            39      0     33
# Cañuelas                              38            36      0     11
# Centro / Microcentro                 159           157     24    152
# Chacarita                            204           198     31    106
# Chascomús                             36            33      0     34
# Coghlan                              239           236     30    141
# Colegiales                           334           326     58    209
# Colón                                 23            22      1     16
# Confluencia                           74            73      1     32
# Congreso                             268           259     47    209
# Constitución                         194           190     20    139
# Coronel Suárez                        23            21      2     60
# Costa Esmeralda                      123           123      0     95
# Cushamen                              63             7      0      1
# ...                                  ...           ...    ...    ...
# Santa Teresita                        26            23      0     12
# Santo Tomé                            31            31      2     29
# Tandil                                57            54      4     30
# Tigre                               8072          7951    540   2941
# Trenque Lauquen                       11            11      7      1
# Tres Arroyos                          63            58      0     71
# Tres de Febrero                     1049           934    250    772
# Tribunales                            66            61     14     44
# Unquillo                              20            20      0      8
# Valeria del Mar                       49            47      4     35
# Velez Sarsfield                       33            33      3     18
# Versalles                             52            50      9     40
# Vicente López                       3443          3371    391    918
# Villa Allende                         97            95     29     66
# Villa Carlos Paz                     414           386      0    345
# Villa Crespo                        1106          1092    141    529
# Villa Devoto                         365           354     45    228
# Villa General Belgrano                30            25      1     46
# Villa General Mitre                   47            47      7     38
# Villa Gesell                         267           255      6    191
# Villa La Angostura                    25            25      0     29
# Villa Lugano                         179           168     16    114
# Villa Luro                           352           316     24    143
# Villa Ortuzar                         77            76      2     38
# Villa Pueyrredón                     169           164      6     88
# Villa Real                            36            36      0     17
# Villa Santa Rita                      54            54     11     39
# Villa Urquiza                       1333          1308    116    554
# Villa del Parque                     436           430     34    177
# Yerba Buena                           20            12      0     18
#
#                         expenses  properati_url  description  title  \
# district_name
# Abasto                        26            103          103    103
# Agronomía                      8             39           39     39
# Almagro                      284           1120         1120   1120
# Almirante Brown               93           1520         1520   1520
# Avellaneda                    62            628          628    628
# Bahía Blanca                  10            456          456    456
# Balcarce                       1             80           80     80
# Balvanera                    191            626          626    626
# Barracas                      56            410          410    410
# Barrio Norte                 340           1078         1078   1078
# Belgrano                     746           2917         2917   2917
# Berazategui                   21            450          450    450
# Boca                          49            216          216    216
# Boedo                         37            867          867    867
# Caballito                    506           2225         2225   2225
# Capitán Bermúdez               0             47           47     47
# Cariló                         1             55           55     55
# Cañuelas                       7             45           45     45
# Centro / Microcentro          29            159          159    159
# Chacarita                     33            219          219    219
# Chascomús                      4             55           55     55
# Coghlan                       38            253          253    253
# Colegiales                    99            342          342    342
# Colón                         14             98           98     98
# Confluencia                    4            113          113    113
# Congreso                      85            284          284    284
# Constitución                  21            199          199    199
# Coronel Suárez                 0             73           73     73
# Costa Esmeralda                5            125          125    125
# Cushamen                       0             71           71     71
# ...                          ...            ...          ...    ...
# Santa Teresita                 5             46           46     46
# Santo Tomé                     1             44           44     44
# Tandil                         2             73           73     73
# Tigre                       1260           8914         8914   8914
# Trenque Lauquen               10             40           40     40
# Tres Arroyos                   0             79           79     79
# Tres de Febrero              101           1256         1256   1256
# Tribunales                    24             71           71     71
# Unquillo                       1             32           32     32
# Valeria del Mar                0             53           53     53
# Velez Sarsfield                5             37           37     37
# Versalles                      3             55           55     55
# Vicente López                352           3555         3555   3555
# Villa Allende                  5            196          196    196
# Villa Carlos Paz              11            573          572    573
# Villa Crespo                 394           1243         1243   1243
# Villa Devoto                  55            389          389    389
# Villa General Belgrano         3             79           79     79
# Villa General Mitre            6             48           48     48
# Villa Gesell                   9            292          292    292
# Villa La Angostura             0            132          132    132
# Villa Lugano                  16            199          199    199
# Villa Luro                    47            411          411    411
# Villa Ortuzar                 23             78           78     78
# Villa Pueyrredón              22            175          175    175
# Villa Real                     2             36           36     36
# Villa Santa Rita               2             55           55     55
# Villa Urquiza                184           1607         1607   1607
# Villa del Parque              91            469          469    469
# Yerba Buena                   22            161          161    161
#
#                         image_thumbnail  city_name
# district_name
# Abasto                               97          0
# Agronomía                            39          0
# Almagro                            1119          0
# Almirante Brown                    1454       1481
# Avellaneda                          627        404
# Bahía Blanca                        454          5
# Balcarce                             80          1
# Balvanera                           624          0
# Barracas                            410          0
# Barrio Norte                       1070          0
# Belgrano                           2888          0
# Berazategui                         450        339
# Boca                                213          0
# Boedo                               867          0
# Caballito                          2192          0
# Capitán Bermúdez                     47          0
# Cariló                               55          0
# Cañuelas                             45         37
# Centro / Microcentro                159          0
# Chacarita                           186          0
# Chascomús                            54         49
# Coghlan                             247          0
# Colegiales                          341          0
# Colón                                98          0
# Confluencia                          74          0
# Congreso                            283          0
# Constitución                        198          0
# Coronel Suárez                       73         61
# Costa Esmeralda                     125          0
# Cushamen                             39          0
# ...                                 ...        ...
# Santa Teresita                       45          0
# Santo Tomé                           42          0
# Tandil                               73         24
# Tigre                              8813       6552
# Trenque Lauquen                      40         32
# Tres Arroyos                         79          0
# Tres de Febrero                    1246       1166
# Tribunales                           71          0
# Unquillo                             32          0
# Valeria del Mar                      53          0
# Velez Sarsfield                      37          0
# Versalles                            55          0
# Vicente López                      3514       3331
# Villa Allende                       191          0
# Villa Carlos Paz                    571          0
# Villa Crespo                       1206          0
# Villa Devoto                        387          0
# Villa General Belgrano               79          0
# Villa General Mitre                  48          0
# Villa Gesell                        292          0
# Villa La Angostura                  132          0
# Villa Lugano                        197          0
# Villa Luro                          411          0
# Villa Ortuzar                        78          0
# Villa Pueyrredón                    174          0
# Villa Real                           36          0
# Villa Santa Rita                     55          0
# Villa Urquiza                      1571          0
# Villa del Parque                    467          0
# Yerba Buena                         155          0
#
# [156 rows x 26 columns]

# %% [markdown]
# Corroboramos que el dataframe 'dfprop_fewlocations' se hayan agregado las propiedaes excluidas

# %% [markdown]
# Corroboramos la cantidad de nan en la variable 'price_usd_per_m2'

# %%
dfprop.isna().sum()
# Out:
# operation                         0
# property_type                     0
# place_name                        0
# place_with_parent_names           0
# country_name                      0
# state_name                        0
# geonames_id                   17696
# lat-lon                       44784
# lat                           44784
# lon                           44784
# price                         13563
# currency                      13563
# price_aprox_local_currency    13563
# price_aprox_usd               13563
# surface_total_in_m2            6506
# surface_covered_in_m2          6506
# price_usd_per_m2              20301
# price_per_m2                  24886
# floor                         98697
# rooms                         62404
# expenses                      92935
# properati_url                     0
# description                       2
# title                             0
# image_thumbnail                2337
# district_name                     0
# city_name                     68162
# dtype: int64

# %% [markdown]
# Habiendo eliminado 'district_names' con menos de 30 operaciones, procedemos a quitar aquellos registros intra-district, donde los NaN alcancen o superen el 50% de total de operaciones.

# %%
# Obtenemos un dataframe con las propiedades sin precio y con district_name 
dfsin_precio=dfprop.loc[dfprop['price_usd_per_m2'].isna() &\
                        (~dfprop['district_name'].isna())].groupby(['state_name','district_name'])[['operation']].count()

# Obtenemos un dataframe con las propiedades con precio y con district_name
dfcon_precio=dfprop.loc[(~dfprop['price_usd_per_m2'].isna()) &\
                        (~dfprop['district_name'].isna())].groupby(['state_name','district_name'])[['operation']].count()

# Unimos ambos dataframe y agrupamos para obtener la cantidad de propiedades sin y con precio para cada district_name
#Agrupamos por state_name y district_name para evitar que distritos de diferentes provincias se agrupen indebidamente 
df_merge=pd.merge(dfsin_precio,dfcon_precio,how='left',on=['state_name','district_name'])

# Renombro columnas a efectos practicos en la interpretacion
df_merge.rename(columns={'operation_x':'sin precio','operation_y':'con precio'},inplace=True)

# Creo una columna para obtener el total de propiedades
df_merge['total']=df_merge['con precio']+df_merge['sin precio']

# Calculo el % de propiedaes sin precio respecto al total de propiedades
df_merge['%']=df_merge['sin precio']/df_merge['total']

# Filtramos los distritos cuya relacion con la cantidad total de propiedades sea mayor a 0.5
df_merge=df_merge.loc[df_merge['%']>0.5]

#Hacemos un merge con dfprop para que las propiedades a ser removidas queden marcadas
dfpropdelete=pd.merge(dfprop,df_merge,how='left',on=['state_name','district_name'])

# Filtro el dataframe para obtener las propiedades a ingresar en dfprop 
dfprop= dfpropdelete.loc[dfpropdelete['total'].isna()|(~dfpropdelete['total'].isna())&(~dfpropdelete['price_usd_per_m2'].isna())]

# eliminon las columnas utilizadas en este analisis
dfprop.drop(['sin precio','con precio','%','total'],axis=1,inplace=True)

# Filtro el dataframe para obtener las propiedades excluidas 
dfpropdelete= dfpropdelete.loc[(~(dfpropdelete['total'].isna()|(~dfpropdelete['total'].isna())&(~dfpropdelete['price_usd_per_m2'].isna())))]

# elimino las columnas utilizadas en este analisis
dfpropdelete.drop(['sin precio','con precio','%','total'],axis=1,inplace=True)

# Agrego las propiedades excluidas al dataframe 
dfprop_fewlocations=dfprop_fewlocations.append(dfpropdelete)

dfprop.shape
# Out:
# /opt/conda/envs/geopandas/lib/python3.7/site-packages/pandas/core/frame.py:3930: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# (103889, 27)

# %%
dfprop.groupby(by=['district_name']).count()
# Out:
#                         operation  property_type  place_name  \
# district_name
# Abasto                        103            103         103
# Agronomía                      39             39          39
# Almagro                      1120           1120        1120
# Almirante Brown              1520           1520        1520
# Avellaneda                    628            628         628
# Bahía Blanca                  456            456         456
# Balcarce                       37             37          37
# Balvanera                     626            626         626
# Barracas                      410            410         410
# Barrio Norte                 1078           1078        1078
# Belgrano                     2917           2917        2917
# Berazategui                   450            450         450
# Boca                          216            216         216
# Boedo                         867            867         867
# Caballito                    2225           2225        2225
# Capitán Bermúdez               47             47          47
# Cariló                         55             55          55
# Cañuelas                       45             45          45
# Centro / Microcentro          159            159         159
# Chacarita                     219            219         219
# Chascomús                      55             55          55
# Coghlan                       253            253         253
# Colegiales                    342            342         342
# Colón                          23             23          23
# Confluencia                   113            113         113
# Congreso                      284            284         284
# Constitución                  199            199         199
# Coronel Suárez                 23             23          23
# Costa Esmeralda               125            125         125
# Cushamen                       71             71          71
# ...                           ...            ...         ...
# Santa Teresita                 46             46          46
# Santo Tomé                     44             44          44
# Tandil                         73             73          73
# Tigre                        8914           8914        8914
# Trenque Lauquen                11             11          11
# Tres Arroyos                   79             79          79
# Tres de Febrero              1256           1256        1256
# Tribunales                     71             71          71
# Unquillo                       32             32          32
# Valeria del Mar                53             53          53
# Velez Sarsfield                37             37          37
# Versalles                      55             55          55
# Vicente López                3555           3555        3555
# Villa Allende                  97             97          97
# Villa Carlos Paz              573            573         573
# Villa Crespo                 1243           1243        1243
# Villa Devoto                  389            389         389
# Villa General Belgrano         30             30          30
# Villa General Mitre            48             48          48
# Villa Gesell                  292            292         292
# Villa La Angostura             25             25          25
# Villa Lugano                  199            199         199
# Villa Luro                    411            411         411
# Villa Ortuzar                  78             78          78
# Villa Pueyrredón              175            175         175
# Villa Real                     36             36          36
# Villa Santa Rita               55             55          55
# Villa Urquiza                1607           1607        1607
# Villa del Parque              469            469         469
# Yerba Buena                    20             20          20
#
#                         place_with_parent_names  country_name  state_name  \
# district_name
# Abasto                                      103           103         103
# Agronomía                                    39            39          39
# Almagro                                    1120          1120        1120
# Almirante Brown                            1520          1520        1520
# Avellaneda                                  628           628         628
# Bahía Blanca                                456           456         456
# Balcarce                                     37            37          37
# Balvanera                                   626           626         626
# Barracas                                    410           410         410
# Barrio Norte                               1078          1078        1078
# Belgrano                                   2917          2917        2917
# Berazategui                                 450           450         450
# Boca                                        216           216         216
# Boedo                                       867           867         867
# Caballito                                  2225          2225        2225
# Capitán Bermúdez                             47            47          47
# Cariló                                       55            55          55
# Cañuelas                                     45            45          45
# Centro / Microcentro                        159           159         159
# Chacarita                                   219           219         219
# Chascomús                                    55            55          55
# Coghlan                                     253           253         253
# Colegiales                                  342           342         342
# Colón                                        23            23          23
# Confluencia                                 113           113         113
# Congreso                                    284           284         284
# Constitución                                199           199         199
# Coronel Suárez                               23            23          23
# Costa Esmeralda                             125           125         125
# Cushamen                                     71            71          71
# ...                                         ...           ...         ...
# Santa Teresita                               46            46          46
# Santo Tomé                                   44            44          44
# Tandil                                       73            73          73
# Tigre                                      8914          8914        8914
# Trenque Lauquen                              11            11          11
# Tres Arroyos                                 79            79          79
# Tres de Febrero                            1256          1256        1256
# Tribunales                                   71            71          71
# Unquillo                                     32            32          32
# Valeria del Mar                              53            53          53
# Velez Sarsfield                              37            37          37
# Versalles                                    55            55          55
# Vicente López                              3555          3555        3555
# Villa Allende                                97            97          97
# Villa Carlos Paz                            573           573         573
# Villa Crespo                               1243          1243        1243
# Villa Devoto                                389           389         389
# Villa General Belgrano                       30            30          30
# Villa General Mitre                          48            48          48
# Villa Gesell                                292           292         292
# Villa La Angostura                           25            25          25
# Villa Lugano                                199           199         199
# Villa Luro                                  411           411         411
# Villa Ortuzar                                78            78          78
# Villa Pueyrredón                            175           175         175
# Villa Real                                   36            36          36
# Villa Santa Rita                             55            55          55
# Villa Urquiza                              1607          1607        1607
# Villa del Parque                            469           469         469
# Yerba Buena                                  20            20          20
#
#                         geonames_id  lat-lon   lat   lon  ...  \
# district_name                                             ...
# Abasto                            0       68    68    68  ...
# Agronomía                        39       39    39    39  ...
# Almagro                        1120      920   920   920  ...
# Almirante Brown                 813      527   527   527  ...
# Avellaneda                      615      396   396   396  ...
# Bahía Blanca                    456      436   436   436  ...
# Balcarce                         37       33    33    33  ...
# Balvanera                       626      558   558   558  ...
# Barracas                        410      357   357   357  ...
# Barrio Norte                   1078      860   860   860  ...
# Belgrano                       2917     1914  1914  1914  ...
# Berazategui                     253      380   380   380  ...
# Boca                            216      127   127   127  ...
# Boedo                           867      321   321   321  ...
# Caballito                      2225     1784  1784  1784  ...
# Capitán Bermúdez                 47       47    47    47  ...
# Cariló                            0       41    41    41  ...
# Cañuelas                         42       31    31    31  ...
# Centro / Microcentro            159      157   157   157  ...
# Chacarita                       219      153   153   153  ...
# Chascomús                         6       42    42    42  ...
# Coghlan                         253      214   214   214  ...
# Colegiales                      342      308   308   308  ...
# Colón                            23        6     6     6  ...
# Confluencia                     113       53    53    53  ...
# Congreso                        284      221   221   221  ...
# Constitución                    199      185   185   185  ...
# Coronel Suárez                   23       14    14    14  ...
# Costa Esmeralda                   0       98    98    98  ...
# Cushamen                         71        0     0     0  ...
# ...                             ...      ...   ...   ...  ...
# Santa Teresita                   46       28    28    28  ...
# Santo Tomé                       44       39    39    39  ...
# Tandil                           73       66    66    66  ...
# Tigre                          3123     4415  4415  4415  ...
# Trenque Lauquen                  11       10    10    10  ...
# Tres Arroyos                     79       73    73    73  ...
# Tres de Febrero                1084     1055  1055  1055  ...
# Tribunales                        0       62    62    62  ...
# Unquillo                         32       12    12    12  ...
# Valeria del Mar                  53       43    43    43  ...
# Velez Sarsfield                  37       35    35    35  ...
# Versalles                        55       55    55    55  ...
# Vicente López                  2884     1233  1233  1233  ...
# Villa Allende                    97       63    63    63  ...
# Villa Carlos Paz                573      498   498   498  ...
# Villa Crespo                   1243      861   861   861  ...
# Villa Devoto                    389      363   363   363  ...
# Villa General Belgrano           30       21    21    21  ...
# Villa General Mitre              48       48    48    48  ...
# Villa Gesell                    292      269   269   269  ...
# Villa La Angostura               25       19    19    19  ...
# Villa Lugano                    199      162   162   162  ...
# Villa Luro                      411      343   343   343  ...
# Villa Ortuzar                    78       65    65    65  ...
# Villa Pueyrredón                175      137   137   137  ...
# Villa Real                       36       35    35    35  ...
# Villa Santa Rita                 55       54    54    54  ...
# Villa Urquiza                  1607     1068  1068  1068  ...
# Villa del Parque                469      312   312   312  ...
# Yerba Buena                      20        8     8     8  ...
#
#                         price_usd_per_m2  price_per_m2  floor  rooms  \
# district_name
# Abasto                                92            88     17     61
# Agronomía                             36            35      2     32
# Almagro                              941           921    149    706
# Almirante Brown                     1070           999      7    156
# Avellaneda                           581           547     28    292
# Bahía Blanca                         351           311      0    269
# Balcarce                              37            32      0     29
# Balvanera                            588           559    141    428
# Barracas                             380           361     26    235
# Barrio Norte                         955           910    100    641
# Belgrano                            2468          2362    189   1141
# Berazategui                          353           345      7    192
# Boca                                 201           192     16     87
# Boedo                                829           824     19    744
# Caballito                           2000          1969    331   1127
# Capitán Bermúdez                      46            46      0      4
# Cariló                                39            39      0     33
# Cañuelas                              38            36      0     11
# Centro / Microcentro                 159           157     24    152
# Chacarita                            204           198     31    106
# Chascomús                             36            33      0     34
# Coghlan                              239           236     30    141
# Colegiales                           334           326     58    209
# Colón                                 23            22      0      2
# Confluencia                           74            73      1     32
# Congreso                             268           259     47    209
# Constitución                         194           190     20    139
# Coronel Suárez                        23            21      0     21
# Costa Esmeralda                      123           123      0     95
# Cushamen                              63             7      0      1
# ...                                  ...           ...    ...    ...
# Santa Teresita                        26            23      0     12
# Santo Tomé                            31            31      2     29
# Tandil                                57            54      4     30
# Tigre                               8072          7951    540   2941
# Trenque Lauquen                       11            11      3      1
# Tres Arroyos                          63            58      0     71
# Tres de Febrero                     1049           934    250    772
# Tribunales                            66            61     14     44
# Unquillo                              20            20      0      8
# Valeria del Mar                       49            47      4     35
# Velez Sarsfield                       33            33      3     18
# Versalles                             52            50      9     40
# Vicente López                       3443          3371    391    918
# Villa Allende                         97            95     23     48
# Villa Carlos Paz                     414           386      0    345
# Villa Crespo                        1106          1092    141    529
# Villa Devoto                         365           354     45    228
# Villa General Belgrano                30            25      1     12
# Villa General Mitre                   47            47      7     38
# Villa Gesell                         267           255      6    191
# Villa La Angostura                    25            25      0     18
# Villa Lugano                         179           168     16    114
# Villa Luro                           352           316     24    143
# Villa Ortuzar                         77            76      2     38
# Villa Pueyrredón                     169           164      6     88
# Villa Real                            36            36      0     17
# Villa Santa Rita                      54            54     11     39
# Villa Urquiza                       1333          1308    116    554
# Villa del Parque                     436           430     34    177
# Yerba Buena                           20            12      0      3
#
#                         expenses  properati_url  description  title  \
# district_name
# Abasto                        26            103          103    103
# Agronomía                      8             39           39     39
# Almagro                      284           1120         1120   1120
# Almirante Brown               93           1520         1520   1520
# Avellaneda                    62            628          628    628
# Bahía Blanca                  10            456          456    456
# Balcarce                       1             37           37     37
# Balvanera                    191            626          626    626
# Barracas                      56            410          410    410
# Barrio Norte                 340           1078         1078   1078
# Belgrano                     746           2917         2917   2917
# Berazategui                   21            450          450    450
# Boca                          49            216          216    216
# Boedo                         37            867          867    867
# Caballito                    506           2225         2225   2225
# Capitán Bermúdez               0             47           47     47
# Cariló                         1             55           55     55
# Cañuelas                       7             45           45     45
# Centro / Microcentro          29            159          159    159
# Chacarita                     33            219          219    219
# Chascomús                      4             55           55     55
# Coghlan                       38            253          253    253
# Colegiales                    99            342          342    342
# Colón                          8             23           23     23
# Confluencia                    4            113          113    113
# Congreso                      85            284          284    284
# Constitución                  21            199          199    199
# Coronel Suárez                 0             23           23     23
# Costa Esmeralda                5            125          125    125
# Cushamen                       0             71           71     71
# ...                          ...            ...          ...    ...
# Santa Teresita                 5             46           46     46
# Santo Tomé                     1             44           44     44
# Tandil                         2             73           73     73
# Tigre                       1260           8914         8914   8914
# Trenque Lauquen                5             11           11     11
# Tres Arroyos                   0             79           79     79
# Tres de Febrero              101           1256         1256   1256
# Tribunales                    24             71           71     71
# Unquillo                       1             32           32     32
# Valeria del Mar                0             53           53     53
# Velez Sarsfield                5             37           37     37
# Versalles                      3             55           55     55
# Vicente López                352           3555         3555   3555
# Villa Allende                  4             97           97     97
# Villa Carlos Paz              11            573          572    573
# Villa Crespo                 394           1243         1243   1243
# Villa Devoto                  55            389          389    389
# Villa General Belgrano         3             30           30     30
# Villa General Mitre            6             48           48     48
# Villa Gesell                   9            292          292    292
# Villa La Angostura             0             25           25     25
# Villa Lugano                  16            199          199    199
# Villa Luro                    47            411          411    411
# Villa Ortuzar                 23             78           78     78
# Villa Pueyrredón              22            175          175    175
# Villa Real                     2             36           36     36
# Villa Santa Rita               2             55           55     55
# Villa Urquiza                184           1607         1607   1607
# Villa del Parque              91            469          469    469
# Yerba Buena                    1             20           20     20
#
#                         image_thumbnail  city_name
# district_name
# Abasto                               97          0
# Agronomía                            39          0
# Almagro                            1119          0
# Almirante Brown                    1454       1481
# Avellaneda                          627        404
# Bahía Blanca                        454          5
# Balcarce                             37          1
# Balvanera                           624          0
# Barracas                            410          0
# Barrio Norte                       1070          0
# Belgrano                           2888          0
# Berazategui                         450        339
# Boca                                213          0
# Boedo                               867          0
# Caballito                          2192          0
# Capitán Bermúdez                     47          0
# Cariló                               55          0
# Cañuelas                             45         37
# Centro / Microcentro                159          0
# Chacarita                           186          0
# Chascomús                            54         49
# Coghlan                             247          0
# Colegiales                          341          0
# Colón                                23          0
# Confluencia                          74          0
# Congreso                            283          0
# Constitución                        198          0
# Coronel Suárez                       23         21
# Costa Esmeralda                     125          0
# Cushamen                             39          0
# ...                                 ...        ...
# Santa Teresita                       45          0
# Santo Tomé                           42          0
# Tandil                               73         24
# Tigre                              8813       6552
# Trenque Lauquen                      11          7
# Tres Arroyos                         79          0
# Tres de Febrero                    1246       1166
# Tribunales                           71          0
# Unquillo                             32          0
# Valeria del Mar                      53          0
# Velez Sarsfield                      37          0
# Versalles                            55          0
# Vicente López                      3514       3331
# Villa Allende                        97          0
# Villa Carlos Paz                    571          0
# Villa Crespo                       1206          0
# Villa Devoto                        387          0
# Villa General Belgrano               30          0
# Villa General Mitre                  48          0
# Villa Gesell                        292          0
# Villa La Angostura                   25          0
# Villa Lugano                        197          0
# Villa Luro                          411          0
# Villa Ortuzar                        78          0
# Villa Pueyrredón                    174          0
# Villa Real                           36          0
# Villa Santa Rita                     55          0
# Villa Urquiza                      1571          0
# Villa del Parque                    467          0
# Yerba Buena                          18          0
#
# [156 rows x 26 columns]

# %% [markdown]
# Corroboramos que el dataframe 'dfprop_fewlocations' se hayan agregado las propiedaes excluidas

# %%
dfprop_fewlocations.shape
# Out:
# (4114, 27)

# %% [markdown]
# Corroboramos la cantidad de nan en la variable 'price_usd_per_m2'

# %%
dfprop.isna().sum()
# Out:
# operation                         0
# property_type                     0
# place_name                        0
# place_with_parent_names           0
# country_name                      0
# state_name                        0
# geonames_id                   17370
# lat-lon                       43845
# lat                           43845
# lon                           43845
# price                         11550
# currency                      11550
# price_aprox_local_currency    11550
# price_aprox_usd               11550
# surface_total_in_m2            6300
# surface_covered_in_m2          6300
# price_usd_per_m2              18082
# price_per_m2                  22667
# floor                         96523
# rooms                         61168
# expenses                      90813
# properati_url                     0
# description                       2
# title                             0
# image_thumbnail                2295
# district_name                     0
# city_name                     66678
# dtype: int64

# %%
dfprop.groupby(by='state_name').count()
# Out:
#                               operation  property_type  place_name  \
# state_name
# Bs.As. G.B.A. Zona Norte          24573          24573       24573
# Bs.As. G.B.A. Zona Oeste           7914           7914        7914
# Bs.As. G.B.A. Zona Sur            12591          12591       12591
# Buenos Aires Costa Atlántica       9232           9232        9232
# Buenos Aires Interior              1534           1534        1534
# Capital Federal                   29555          29555       29555
# Chubut                              109            109         109
# Corrientes                          530            530         530
# Córdoba                            7826           7826        7826
# Entre Ríos                           69             69          69
# Formosa                              29             29          29
# La Pampa                             15             15          15
# Mendoza                             295            295         295
# Misiones                            351            351         351
# Neuquén                             395            395         395
# Río Negro                           254            254         254
# Salta                                91             91          91
# San Luis                            152            152         152
# Santa Fe                           8241           8241        8241
# Tucumán                             133            133         133
#
#                               place_with_parent_names  country_name  \
# state_name
# Bs.As. G.B.A. Zona Norte                        24573         24573
# Bs.As. G.B.A. Zona Oeste                         7914          7914
# Bs.As. G.B.A. Zona Sur                          12591         12591
# Buenos Aires Costa Atlántica                     9232          9232
# Buenos Aires Interior                            1534          1534
# Capital Federal                                 29555         29555
# Chubut                                            109           109
# Corrientes                                        530           530
# Córdoba                                          7826          7826
# Entre Ríos                                         69            69
# Formosa                                            29            29
# La Pampa                                           15            15
# Mendoza                                           295           295
# Misiones                                          351           351
# Neuquén                                           395           395
# Río Negro                                         254           254
# Salta                                              91            91
# San Luis                                          152           152
# Santa Fe                                         8241          8241
# Tucumán                                           133           133
#
#                               geonames_id  lat-lon    lat    lon  price  ...  \
# state_name                                                               ...
# Bs.As. G.B.A. Zona Norte            14602    11188  11188  11188  23326  ...
# Bs.As. G.B.A. Zona Oeste             6910     4484   4484   4484   6967  ...
# Bs.As. G.B.A. Zona Sur               8461     5214   5214   5214  11504  ...
# Buenos Aires Costa Atlántica         8228     7600   7600   7600   8600  ...
# Buenos Aires Interior                1482      958    958    958   1410  ...
# Capital Federal                     28346    21897  21897  21897  26921  ...
# Chubut                                109        0      0      0    106  ...
# Corrientes                            530        2      2      2    448  ...
# Córdoba                              7826     3896   3896   3896   6298  ...
# Entre Ríos                             69       48     48     48     68  ...
# Formosa                                29        0      0      0     29  ...
# La Pampa                               15        4      4      4     15  ...
# Mendoza                               295       58     58     58    281  ...
# Misiones                              351      284    284    284    256  ...
# Neuquén                               395      304    304    304    298  ...
# Río Negro                             254      152    152    152    251  ...
# Salta                                  91       74     74     74     69  ...
# San Luis                              152       79     79     79    134  ...
# Santa Fe                             8241     3775   3775   3775   5225  ...
# Tucumán                               133       27     27     27    133  ...
#
#                               price_per_m2  floor  rooms  expenses  \
# state_name
# Bs.As. G.B.A. Zona Norte             21868   1772   6870      2980
# Bs.As. G.B.A. Zona Oeste              6061    557   4043       608
# Bs.As. G.B.A. Zona Sur                9513    235   2428      1725
# Buenos Aires Costa Atlántica          6608    147   7350       416
# Buenos Aires Interior                 1131      8    626        64
# Capital Federal                      25438   2924  15132      6249
# Chubut                                  27      0      1         0
# Corrientes                             403      0      1        65
# Córdoba                               4459   1209   3230       564
# Entre Ríos                              66      0      7         9
# Formosa                                  0      0      0         1
# La Pampa                                15      0      0         2
# Mendoza                                252      5     21        45
# Misiones                               172     75    207         1
# Neuquén                                254     76    245        19
# Río Negro                              178     15    129         6
# Salta                                   55      9     37         0
# San Luis                               110      1     25         5
# Santa Fe                              4525    333   2350       296
# Tucumán                                 87      0     19        21
#
#                               properati_url  description  title  \
# state_name
# Bs.As. G.B.A. Zona Norte              24573        24572  24573
# Bs.As. G.B.A. Zona Oeste               7914         7914   7914
# Bs.As. G.B.A. Zona Sur                12591        12591  12591
# Buenos Aires Costa Atlántica           9232         9232   9232
# Buenos Aires Interior                  1534         1534   1534
# Capital Federal                       29555        29555  29555
# Chubut                                  109          109    109
# Corrientes                              530          530    530
# Córdoba                                7826         7825   7826
# Entre Ríos                               69           69     69
# Formosa                                  29           29     29
# La Pampa                                 15           15     15
# Mendoza                                 295          295    295
# Misiones                                351          351    351
# Neuquén                                 395          395    395
# Río Negro                               254          254    254
# Salta                                    91           91     91
# San Luis                                152          152    152
# Santa Fe                               8241         8241   8241
# Tucumán                                 133          133    133
#
#                               image_thumbnail  district_name  city_name
# state_name
# Bs.As. G.B.A. Zona Norte                24275          24573      17211
# Bs.As. G.B.A. Zona Oeste                 7637           7914       6321
# Bs.As. G.B.A. Zona Sur                  12201          12591      10532
# Buenos Aires Costa Atlántica             9159           9232       1128
# Buenos Aires Interior                    1519           1534        650
# Capital Federal                         29108          29555       1156
# Chubut                                     76            109          0
# Corrientes                                528            530          0
# Córdoba                                  7539           7826          0
# Entre Ríos                                 69             69          0
# Formosa                                    29             29          0
# La Pampa                                   14             15          0
# Mendoza                                   293            295          0
# Misiones                                  343            351          0
# Neuquén                                   355            395          0
# Río Negro                                 221            254        213
# Salta                                      90             91          0
# San Luis                                  152            152          0
# Santa Fe                                 7856           8241          0
# Tucumán                                   130            133          0
#
# [20 rows x 26 columns]

# %%
#Creamos dataframe con un valor booleano que indica si la provincia tiene menos de 30 propiedades (True) o no (False).
dfprop_stateless30locations=dfprop.groupby('state_name')[['operation']].count()<30

# Renombramos la columna  
dfprop_stateless30locations.rename(columns={'state_name':'state_name','operation':'less_30_locations'},inplace=True)

# Hacemos un merge con dfprop para marcar cada una de las propiedades
dfprop=pd.merge(dfprop,dfprop_stateless30locations,how='left',on='state_name')
    
# Generamos un nuevo Dataframe para almacenar las propiedades correspondientes a provincias con menos de 30 propiedades
dfprop_fewlocations=dfprop.loc[dfprop['less_30_locations']==True]

# Eliminamos del dataframe proncipal dichas ubiaciones
dfprop=dfprop.loc[dfprop['less_30_locations']==False]

#Eliminamos las columnas de ambos dataframes
dfprop_fewlocations.drop(['less_30_locations'],axis=1,inplace=True)
dfprop.drop(['less_30_locations'],axis=1,inplace=True)

#Verificamos la cantidad de ubicaciones dentro del dataframe auxiliar
dfprop_fewlocations.shape
# Out:
# (44, 27)

# %%
dfprop.groupby(by='state_name').count()
# Out:
#                               operation  property_type  place_name  \
# state_name
# Bs.As. G.B.A. Zona Norte          24573          24573       24573
# Bs.As. G.B.A. Zona Oeste           7914           7914        7914
# Bs.As. G.B.A. Zona Sur            12591          12591       12591
# Buenos Aires Costa Atlántica       9232           9232        9232
# Buenos Aires Interior              1534           1534        1534
# Capital Federal                   29555          29555       29555
# Chubut                              109            109         109
# Corrientes                          530            530         530
# Córdoba                            7826           7826        7826
# Entre Ríos                           69             69          69
# Mendoza                             295            295         295
# Misiones                            351            351         351
# Neuquén                             395            395         395
# Río Negro                           254            254         254
# Salta                                91             91          91
# San Luis                            152            152         152
# Santa Fe                           8241           8241        8241
# Tucumán                             133            133         133
#
#                               place_with_parent_names  country_name  \
# state_name
# Bs.As. G.B.A. Zona Norte                        24573         24573
# Bs.As. G.B.A. Zona Oeste                         7914          7914
# Bs.As. G.B.A. Zona Sur                          12591         12591
# Buenos Aires Costa Atlántica                     9232          9232
# Buenos Aires Interior                            1534          1534
# Capital Federal                                 29555         29555
# Chubut                                            109           109
# Corrientes                                        530           530
# Córdoba                                          7826          7826
# Entre Ríos                                         69            69
# Mendoza                                           295           295
# Misiones                                          351           351
# Neuquén                                           395           395
# Río Negro                                         254           254
# Salta                                              91            91
# San Luis                                          152           152
# Santa Fe                                         8241          8241
# Tucumán                                           133           133
#
#                               geonames_id  lat-lon    lat    lon  price  ...  \
# state_name                                                               ...
# Bs.As. G.B.A. Zona Norte            14602    11188  11188  11188  23326  ...
# Bs.As. G.B.A. Zona Oeste             6910     4484   4484   4484   6967  ...
# Bs.As. G.B.A. Zona Sur               8461     5214   5214   5214  11504  ...
# Buenos Aires Costa Atlántica         8228     7600   7600   7600   8600  ...
# Buenos Aires Interior                1482      958    958    958   1410  ...
# Capital Federal                     28346    21897  21897  21897  26921  ...
# Chubut                                109        0      0      0    106  ...
# Corrientes                            530        2      2      2    448  ...
# Córdoba                              7826     3896   3896   3896   6298  ...
# Entre Ríos                             69       48     48     48     68  ...
# Mendoza                               295       58     58     58    281  ...
# Misiones                              351      284    284    284    256  ...
# Neuquén                               395      304    304    304    298  ...
# Río Negro                             254      152    152    152    251  ...
# Salta                                  91       74     74     74     69  ...
# San Luis                              152       79     79     79    134  ...
# Santa Fe                             8241     3775   3775   3775   5225  ...
# Tucumán                               133       27     27     27    133  ...
#
#                               price_per_m2  floor  rooms  expenses  \
# state_name
# Bs.As. G.B.A. Zona Norte             21868   1772   6870      2980
# Bs.As. G.B.A. Zona Oeste              6061    557   4043       608
# Bs.As. G.B.A. Zona Sur                9513    235   2428      1725
# Buenos Aires Costa Atlántica          6608    147   7350       416
# Buenos Aires Interior                 1131      8    626        64
# Capital Federal                      25438   2924  15132      6249
# Chubut                                  27      0      1         0
# Corrientes                             403      0      1        65
# Córdoba                               4459   1209   3230       564
# Entre Ríos                              66      0      7         9
# Mendoza                                252      5     21        45
# Misiones                               172     75    207         1
# Neuquén                                254     76    245        19
# Río Negro                              178     15    129         6
# Salta                                   55      9     37         0
# San Luis                               110      1     25         5
# Santa Fe                              4525    333   2350       296
# Tucumán                                 87      0     19        21
#
#                               properati_url  description  title  \
# state_name
# Bs.As. G.B.A. Zona Norte              24573        24572  24573
# Bs.As. G.B.A. Zona Oeste               7914         7914   7914
# Bs.As. G.B.A. Zona Sur                12591        12591  12591
# Buenos Aires Costa Atlántica           9232         9232   9232
# Buenos Aires Interior                  1534         1534   1534
# Capital Federal                       29555        29555  29555
# Chubut                                  109          109    109
# Corrientes                              530          530    530
# Córdoba                                7826         7825   7826
# Entre Ríos                               69           69     69
# Mendoza                                 295          295    295
# Misiones                                351          351    351
# Neuquén                                 395          395    395
# Río Negro                               254          254    254
# Salta                                    91           91     91
# San Luis                                152          152    152
# Santa Fe                               8241         8241   8241
# Tucumán                                 133          133    133
#
#                               image_thumbnail  district_name  city_name
# state_name
# Bs.As. G.B.A. Zona Norte                24275          24573      17211
# Bs.As. G.B.A. Zona Oeste                 7637           7914       6321
# Bs.As. G.B.A. Zona Sur                  12201          12591      10532
# Buenos Aires Costa Atlántica             9159           9232       1128
# Buenos Aires Interior                    1519           1534        650
# Capital Federal                         29108          29555       1156
# Chubut                                     76            109          0
# Corrientes                                528            530          0
# Córdoba                                  7539           7826          0
# Entre Ríos                                 69             69          0
# Mendoza                                   293            295          0
# Misiones                                  343            351          0
# Neuquén                                   355            395          0
# Río Negro                                 221            254        213
# Salta                                      90             91          0
# San Luis                                  152            152          0
# Santa Fe                                 7856           8241          0
# Tucumán                                   130            133          0
#
# [18 rows x 26 columns]

# %%
dfprop.head()
# Out:
#   operation property_type place_name  \
# 0      sell            PH  Mataderos
# 1      sell     apartment   La Plata
# 2      sell     apartment  Mataderos
# 3      sell            PH    Liniers
# 4      sell     apartment     Centro
#
#                              place_with_parent_names country_name  \
# 0              |Argentina|Capital Federal|Mataderos|    Argentina
# 1        |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2              |Argentina|Capital Federal|Mataderos|    Argentina
# 3                |Argentina|Capital Federal|Liniers|    Argentina
# 4  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
#
#                      state_name  geonames_id                  lat-lon  \
# 0               Capital Federal    3430787.0  -34.6618237,-58.5088387
# 1        Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295
# 2               Capital Federal    3430787.0  -34.6522615,-58.5229825
# 3               Capital Federal    3431333.0  -34.6477969,-58.5164244
# 4  Buenos Aires Costa Atlántica    3435548.0  -38.0026256,-57.5494468
#
#          lat        lon  ...  price_per_m2 floor  rooms  expenses  \
# 0 -34.661824 -58.508839  ...   1550.000000   NaN    NaN       NaN
# 1 -34.903883 -57.964330  ...           NaN   NaN    NaN       NaN
# 2 -34.652262 -58.522982  ...   1309.090909   NaN    NaN       NaN
# 3 -34.647797 -58.516424  ...           NaN   NaN    NaN       NaN
# 4 -38.002626 -57.549447  ...   1828.571429   NaN    NaN       NaN
#
#                                        properati_url  \
# 0  http://www.properati.com.ar/15bo8_venta_ph_mat...
# 1  http://www.properati.com.ar/15bob_venta_depart...
# 2  http://www.properati.com.ar/15bod_venta_depart...
# 3  http://www.properati.com.ar/15boh_venta_ph_lin...
# 4  http://www.properati.com.ar/15bok_venta_depart...
#
#                                          description  \
# 0  2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1  Venta de departamento en décimo piso al frente...
# 2  2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3  PH 3 ambientes con patio. Hay 3 deptos en lote...
# 4  DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...
#
#                                                title  \
# 0                 2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1  VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2           2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                       PH 3 amb. cfte. reciclado
# 4  DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
#
#                                      image_thumbnail  district_name  city_name
# 0  https://thumbs4.properati.com/8/BluUYiHJLhgIIK...      Mataderos        NaN
# 1  https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...       La Plata        NaN
# 2  https://thumbs4.properati.com/5/SXKr34F_IwG3W_...      Mataderos        NaN
# 3  https://thumbs4.properati.com/3/DgIfX-85Mog5SP...        Liniers        NaN
# 4  https://thumbs4.properati.com/5/xrRqlNcSI_vs-f...  Mar del Plata     Centro
#
# [5 rows x 27 columns]

# %%
dfprop['description']=dfprop['description'].str.upper()
dfprop['title']=dfprop['title'].str.upper()
dfprop.head()
# Out:
#   operation property_type place_name  \
# 0      sell            PH  Mataderos
# 1      sell     apartment   La Plata
# 2      sell     apartment  Mataderos
# 3      sell            PH    Liniers
# 4      sell     apartment     Centro
#
#                              place_with_parent_names country_name  \
# 0              |Argentina|Capital Federal|Mataderos|    Argentina
# 1        |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2              |Argentina|Capital Federal|Mataderos|    Argentina
# 3                |Argentina|Capital Federal|Liniers|    Argentina
# 4  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
#
#                      state_name  geonames_id                  lat-lon  \
# 0               Capital Federal    3430787.0  -34.6618237,-58.5088387
# 1        Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295
# 2               Capital Federal    3430787.0  -34.6522615,-58.5229825
# 3               Capital Federal    3431333.0  -34.6477969,-58.5164244
# 4  Buenos Aires Costa Atlántica    3435548.0  -38.0026256,-57.5494468
#
#          lat        lon  ...  price_per_m2 floor  rooms  expenses  \
# 0 -34.661824 -58.508839  ...   1550.000000   NaN    NaN       NaN
# 1 -34.903883 -57.964330  ...           NaN   NaN    NaN       NaN
# 2 -34.652262 -58.522982  ...   1309.090909   NaN    NaN       NaN
# 3 -34.647797 -58.516424  ...           NaN   NaN    NaN       NaN
# 4 -38.002626 -57.549447  ...   1828.571429   NaN    NaN       NaN
#
#                                        properati_url  \
# 0  http://www.properati.com.ar/15bo8_venta_ph_mat...
# 1  http://www.properati.com.ar/15bob_venta_depart...
# 2  http://www.properati.com.ar/15bod_venta_depart...
# 3  http://www.properati.com.ar/15boh_venta_ph_lin...
# 4  http://www.properati.com.ar/15bok_venta_depart...
#
#                                          description  \
# 0  2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1  VENTA DE DEPARTAMENTO EN DÉCIMO PISO AL FRENTE...
# 2  2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3  PH 3 AMBIENTES CON PATIO. HAY 3 DEPTOS EN LOTE...
# 4  DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...
#
#                                                title  \
# 0                 2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1  VENTA DEPTO 2 DORM. A ESTRENAR 7 E/ 36 Y 37   ...
# 2           2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                       PH 3 AMB. CFTE. RECICLADO
# 4  DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
#
#                                      image_thumbnail  district_name  city_name
# 0  https://thumbs4.properati.com/8/BluUYiHJLhgIIK...      Mataderos        NaN
# 1  https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...       La Plata        NaN
# 2  https://thumbs4.properati.com/5/SXKr34F_IwG3W_...      Mataderos        NaN
# 3  https://thumbs4.properati.com/3/DgIfX-85Mog5SP...        Liniers        NaN
# 4  https://thumbs4.properati.com/5/xrRqlNcSI_vs-f...  Mar del Plata     Centro
#
# [5 rows x 27 columns]

# %%
dfprop['amb_aux1']=dfprop['description'].str.find('AMB')
dfprop.head(20)
# Out:
#    operation property_type      place_name  \
# 0       sell            PH       Mataderos
# 1       sell     apartment        La Plata
# 2       sell     apartment       Mataderos
# 3       sell            PH         Liniers
# 4       sell     apartment          Centro
# 5       sell            PH           Munro
# 6       sell     apartment        Belgrano
# 7       sell     apartment        Belgrano
# 8       sell         house         Rosario
# 9       sell         house         Córdoba
# 10      sell         house      San Miguel
# 11      sell     apartment        Martínez
# 12      sell     apartment    Palermo Soho
# 13      sell     apartment    Palermo Soho
# 14      sell         house     Bella Vista
# 15      sell            PH       Mataderos
# 16      sell     apartment  Barrio El Golf
# 17      sell         house           Tigre
# 18      sell     apartment         Palermo
# 19      sell     apartment         Palermo
#
#                               place_with_parent_names country_name  \
# 0               |Argentina|Capital Federal|Mataderos|    Argentina
# 1         |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2               |Argentina|Capital Federal|Mataderos|    Argentina
# 3                 |Argentina|Capital Federal|Liniers|    Argentina
# 4   |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 5   |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...    Argentina
# 6                |Argentina|Capital Federal|Belgrano|    Argentina
# 7                |Argentina|Capital Federal|Belgrano|    Argentina
# 8                        |Argentina|Santa Fe|Rosario|    Argentina
# 9                         |Argentina|Córdoba|Córdoba|    Argentina
# 10    |Argentina|Bs.As. G.B.A. Zona Norte|San Miguel|    Argentina
# 11  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 12   |Argentina|Capital Federal|Palermo|Palermo Soho|    Argentina
# 13   |Argentina|Capital Federal|Palermo|Palermo Soho|    Argentina
# 14  |Argentina|Bs.As. G.B.A. Zona Norte|San Miguel...    Argentina
# 15              |Argentina|Capital Federal|Mataderos|    Argentina
# 16  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Nord...    Argentina
# 17         |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|    Argentina
# 18                |Argentina|Capital Federal|Palermo|    Argentina
# 19                |Argentina|Capital Federal|Palermo|    Argentina
#
#                       state_name  geonames_id                        lat-lon  \
# 0                Capital Federal    3430787.0        -34.6618237,-58.5088387
# 1         Bs.As. G.B.A. Zona Sur    3432039.0        -34.9038831,-57.9643295
# 2                Capital Federal    3430787.0        -34.6522615,-58.5229825
# 3                Capital Federal    3431333.0        -34.6477969,-58.5164244
# 4   Buenos Aires Costa Atlántica    3435548.0        -38.0026256,-57.5494468
# 5       Bs.As. G.B.A. Zona Norte    3430511.0        -34.5329567,-58.5217825
# 6                Capital Federal    3436077.0         -34.5598729,-58.443362
# 7                Capital Federal    3436077.0         -34.5598729,-58.443362
# 8                       Santa Fe    3838574.0         -32.942031,-60.7259192
# 9                        Córdoba    3860259.0        -31.4200833,-64.1887761
# 10      Bs.As. G.B.A. Zona Norte          NaN        -34.5390571,-58.7196093
# 11      Bs.As. G.B.A. Zona Norte    3430813.0        -34.4860195,-58.5038139
# 12               Capital Federal    3430234.0                            NaN
# 13               Capital Federal    3430234.0                            NaN
# 14      Bs.As. G.B.A. Zona Norte    3436061.0  -34.5879112015,-58.6987828445
# 15               Capital Federal    3430787.0  -34.6523561177,-58.5016239381
# 16      Bs.As. G.B.A. Zona Norte          NaN  -34.4087174767,-58.6343892841
# 17      Bs.As. G.B.A. Zona Norte    3427753.0         -34.425087,-58.5796585
# 18               Capital Federal    3430234.0   -34.580503566,-58.4058744847
# 19               Capital Federal    3430234.0         -34.590926,-58.4116653
#
#           lat        lon  ...  floor rooms  expenses  \
# 0  -34.661824 -58.508839  ...    NaN   NaN       NaN
# 1  -34.903883 -57.964330  ...    NaN   NaN       NaN
# 2  -34.652262 -58.522982  ...    NaN   NaN       NaN
# 3  -34.647797 -58.516424  ...    NaN   NaN       NaN
# 4  -38.002626 -57.549447  ...    NaN   NaN       NaN
# 5  -34.532957 -58.521782  ...    NaN   NaN       NaN
# 6  -34.559873 -58.443362  ...    NaN   NaN       NaN
# 7  -34.559873 -58.443362  ...    NaN   NaN       NaN
# 8  -32.942031 -60.725919  ...    NaN   NaN       NaN
# 9  -31.420083 -64.188776  ...    NaN   NaN       NaN
# 10 -34.539057 -58.719609  ...    NaN   NaN       NaN
# 11 -34.486019 -58.503814  ...    NaN   NaN       NaN
# 12        NaN        NaN  ...    NaN   1.0       NaN
# 13        NaN        NaN  ...    NaN   1.0       NaN
# 14 -34.587911 -58.698783  ...    NaN   NaN       NaN
# 15 -34.652356 -58.501624  ...    NaN   4.0       NaN
# 16 -34.408717 -58.634389  ...    NaN   3.0       NaN
# 17 -34.425087 -58.579659  ...    NaN   NaN       NaN
# 18 -34.580504 -58.405874  ...    NaN   3.0       NaN
# 19 -34.590926 -58.411665  ...    NaN   4.0       NaN
#
#                                         properati_url  \
# 0   http://www.properati.com.ar/15bo8_venta_ph_mat...
# 1   http://www.properati.com.ar/15bob_venta_depart...
# 2   http://www.properati.com.ar/15bod_venta_depart...
# 3   http://www.properati.com.ar/15boh_venta_ph_lin...
# 4   http://www.properati.com.ar/15bok_venta_depart...
# 5   http://www.properati.com.ar/15bor_venta_ph_mun...
# 6   http://www.properati.com.ar/15bot_venta_depart...
# 7   http://www.properati.com.ar/15bou_venta_depart...
# 8   http://www.properati.com.ar/15box_venta_casa_r...
# 9   http://www.properati.com.ar/15boy_venta_casa_c...
# 10  http://www.properati.com.ar/15bp0_venta_casa_s...
# 11  http://www.properati.com.ar/15bp4_venta_depart...
# 12  http://www.properati.com.ar/15bp9_venta_depart...
# 13  http://www.properati.com.ar/15bpa_venta_depart...
# 14  http://www.properati.com.ar/15bpd_venta_casa_b...
# 15  http://www.properati.com.ar/15bpj_venta_ph_mat...
# 16  http://www.properati.com.ar/15bpl_venta_depart...
# 17  http://www.properati.com.ar/15bq1_venta_casa_t...
# 18  http://www.properati.com.ar/15bq8_venta_depart...
# 19  http://www.properati.com.ar/15bqd_venta_depart...
#
#                                           description  \
# 0   2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1   VENTA DE DEPARTAMENTO EN DÉCIMO PISO AL FRENTE...
# 2   2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3   PH 3 AMBIENTES CON PATIO. HAY 3 DEPTOS EN LOTE...
# 4   DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...
# 5   MUY BUEN PH AL FRENTE CON ENTRADA INDEPENDIENT...
# 6   EXCELENTE MONOAMBIENTE A ESTRENAR AMPLIO SUPER...
# 7   EXCELENTE DOS AMBIENTES  ESTRENAR AMPLIO SUPER...
# 8   MEDNOZA AL 7600A UNA CUADRA DE CALLE MENDOZAWH...
# 9   HERMOSA CASA SIN TERMINAR DE 3 DORMITORIOS, BA...
# 10  ENTRADA DE COCHE, JARDIN, LIVING EN DESNIVEL, ...
# 11  EXCELENTE DEPARTAMENTO 2 AMBIENTES CONTRAFRENT...
# 12   TORRE I MONDRIAN. 3 AMBIENTES CON TERRAZA Y D...
# 13  TORRE II DALÍ. AMBIENTE UNICO DIVISIBLE.VITRAU...
# 14  ULTIMA UNIDAD DISPONIBLEHAUS BOULEVARD: METROS...
# 15  VENTAS MATADEROS AL FRENTE DUPLEX 4 AMB.- PLAN...
# 16  EXCELENTE 3 AMBIENTES EN UN 6 PISO Y CON TERRA...
# 17  CASA SOBRE LOTE AL GOLF EN BARRIO SAN ISIDRO L...
# 18  EXCELENTE SEMIPISO AL CONTRA FRENTE EN BULNES ...
# 19  EXCELENTE ZONA, MULTIPLES MEDIOS DE TRANSPORTE...
#
#                                                 title  \
# 0                  2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1   VENTA DEPTO 2 DORM. A ESTRENAR 7 E/ 36 Y 37   ...
# 2            2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                        PH 3 AMB. CFTE. RECICLADO
# 4   DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
# 5   MUY BUEN PH AL FRENTE DOS DORMITORIOS , PATIO,...
# 6   JOSE HERNANDEZ 1400 MONOAMBIENTE  ESTRENAR CAT...
# 7   JOSE HERNANDEZ   1400 DOS AMBIENTES ESTRENAR ,...
# 8          WHITE 7637 - 2 DORMITORIOS CON PATIO
# 9   CASA SIN TERMINAR EN FALDA DE CAÑETE.         ...
# 10                                            CHALET
# 11  EXCELENTE DEPARTAMENTO 2 AMBIENTES CONTRAFRENT...
# 12                                    VITRAUX PALERMO
# 13                                    VITRAUX PALERMO
# 14  HAUS VILLAGE / BELLA VISTA / 115M² MAS PATIO /...
# 15                      VENTA-MATADEROS-DUPLEX 4 AMB.
# 16  3 AMBIENTES EN VENTA EN ACQUA GOLF 1 EN NORDEL...
# 17  CASA EN VENTA EN BARRIO SAN ISIDRO LABRADOR, T...
# 18  BULNES Y LIBERTADOR: ESPECTACULAR PULMÓN, CON ...
# 19    DEPARTAMENTO DE 4 AMBIENTES EN VENTA EN PALERMO
#
#                                       image_thumbnail  district_name  \
# 0   https://thumbs4.properati.com/8/BluUYiHJLhgIIK...      Mataderos
# 1   https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...       La Plata
# 2   https://thumbs4.properati.com/5/SXKr34F_IwG3W_...      Mataderos
# 3   https://thumbs4.properati.com/3/DgIfX-85Mog5SP...        Liniers
# 4   https://thumbs4.properati.com/5/xrRqlNcSI_vs-f...  Mar del Plata
# 5   https://thumbs4.properati.com/5/6GOXsHCyDu1aGx...  Vicente López
# 6   https://thumbs4.properati.com/1/IHxARynlr8sPEW...       Belgrano
# 7   https://thumbs4.properati.com/2/J3zOjgaFHrkvnv...       Belgrano
# 8   https://thumbs4.properati.com/8/RCf1YEWdF4rv98...        Rosario
# 9   https://thumbs4.properati.com/3/mQkhIxXpTTbMSc...        Córdoba
# 10  https://thumbs4.properati.com/4/pH0MnS_2zCGOHR...     San Miguel
# 11  https://thumbs4.properati.com/6/wgSui4rTYqPncO...     San Isidro
# 12  https://thumbs4.properati.com/2/ZTUjkRzTz6YvcU...        Palermo
# 13  https://thumbs4.properati.com/8/Uay2dC732CNlRw...        Palermo
# 14  https://thumbs4.properati.com/6/F7EIhDPQfafSlp...     San Miguel
# 15  https://thumbs4.properati.com/7/XSdJtiE8ZkWgon...      Mataderos
# 16  https://thumbs4.properati.com/8/txJsOWitsI5tjM...          Tigre
# 17  https://thumbs4.properati.com/6/4N9cpurqmDMKEX...          Tigre
# 18  https://thumbs4.properati.com/8/1y9fKHLee-aQQj...        Palermo
# 19  https://thumbs4.properati.com/0/P6wPIXB1wJFLVU...        Palermo
#
#        city_name  amb_aux1
# 0            NaN       2.0
# 1            NaN      -1.0
# 2            NaN       2.0
# 3            NaN       5.0
# 4         Centro      -1.0
# 5          Munro      -1.0
# 6            NaN      14.0
# 7            NaN      14.0
# 8            NaN      -1.0
# 9            NaN      -1.0
# 10           NaN     155.0
# 11      Martínez      25.0
# 12  Palermo Soho      21.0
# 13  Palermo Soho      15.0
# 14   Bella Vista      -1.0
# 15           NaN      36.0
# 16      Nordelta      12.0
# 17           NaN     398.0
# 18           NaN     348.0
# 19           NaN      -1.0
#
# [20 rows x 28 columns]

# %%
dfprop.dtypes
# Out:
# operation                      object
# property_type                  object
# place_name                     object
# place_with_parent_names        object
# country_name                   object
# state_name                     object
# geonames_id                   float64
# lat-lon                        object
# lat                           float64
# lon                           float64
# price                         float64
# currency                       object
# price_aprox_local_currency    float64
# price_aprox_usd               float64
# surface_total_in_m2           float64
# surface_covered_in_m2         float64
# price_usd_per_m2              float64
# price_per_m2                  float64
# floor                         float64
# rooms                         float64
# expenses                      float64
# properati_url                  object
# description                    object
# title                          object
# image_thumbnail                object
# district_name                  object
# city_name                      object
# amb_aux1                      float64
# dtype: object

# %%
dfprop.groupby('amb_aux1').count()
# Out:
#           operation  property_type  place_name  place_with_parent_names  \
# amb_aux1
# -1.0          44542          44542       44542                    44542
#  0.0            199            199         199                      199
#  1.0             43             43          43                       43
#  2.0           1359           1359        1359                     1359
#  3.0             88             88          88                       88
#  4.0           1047           1047        1047                     1047
#  5.0            372            372         372                      372
#  6.0             78             78          78                       78
#  7.0            502            502         502                      502
#  8.0            597            597         597                      597
#  9.0            486            486         486                      486
#  10.0           731            731         731                      731
#  11.0           631            631         631                      631
#  12.0          1156           1156        1156                     1156
#  13.0           443            443         443                      443
#  14.0           727            727         727                      727
#  15.0          1639           1639        1639                     1639
#  16.0          1726           1726        1726                     1726
#  17.0           925            925         925                      925
#  18.0          2439           2439        2439                     2439
#  19.0           624            624         624                      624
#  20.0           871            871         871                      871
#  21.0          1239           1239        1239                     1239
#  22.0           464            464         464                      464
#  23.0           494            494         494                      494
#  24.0          2687           2687        2687                     2687
#  25.0           709            709         709                      709
#  26.0           810            810         810                      810
#  27.0           666            666         666                      666
#  28.0           982            982         982                      982
# ...             ...            ...         ...                      ...
#  2578.0           1              1           1                        1
#  2579.0           1              1           1                        1
#  2594.0           1              1           1                        1
#  2610.0           1              1           1                        1
#  2689.0           1              1           1                        1
#  2692.0           1              1           1                        1
#  2741.0           1              1           1                        1
#  2762.0           2              2           2                        2
#  2794.0           1              1           1                        1
#  2928.0           1              1           1                        1
#  2992.0           1              1           1                        1
#  3080.0           1              1           1                        1
#  3102.0           1              1           1                        1
#  3239.0           1              1           1                        1
#  3308.0           1              1           1                        1
#  3521.0           1              1           1                        1
#  3522.0           1              1           1                        1
#  3542.0           2              2           2                        2
#  3598.0           1              1           1                        1
#  3690.0           2              2           2                        2
#  3882.0           1              1           1                        1
#  3923.0           1              1           1                        1
#  3966.0           1              1           1                        1
#  4015.0           8              8           8                        8
#  4161.0           1              1           1                        1
#  4521.0           1              1           1                        1
#  4772.0           1              1           1                        1
#  4981.0           1              1           1                        1
#  5005.0           1              1           1                        1
#  5027.0           1              1           1                        1
#
#           country_name  state_name  geonames_id  lat-lon    lat    lon  ...  \
# amb_aux1                                                                ...
# -1.0             44542       44542        37366    22735  22735  22735  ...
#  0.0               199         199          186      170    170    170  ...
#  1.0                43          43           39       35     35     35  ...
#  2.0              1359        1359         1262     1063   1063   1063  ...
#  3.0                88          88           84       69     69     69  ...
#  4.0              1047        1047          954      581    581    581  ...
#  5.0               372         372          339      243    243    243  ...
#  6.0                78          78           64       38     38     38  ...
#  7.0               502         502          428      346    346    346  ...
#  8.0               597         597          537      453    453    453  ...
#  9.0               486         486          417      275    275    275  ...
#  10.0              731         731          622      462    462    462  ...
#  11.0              631         631          545      338    338    338  ...
#  12.0             1156        1156          990      647    647    647  ...
#  13.0              443         443          362      229    229    229  ...
#  14.0              727         727          610      487    487    487  ...
#  15.0             1639        1639         1424     1030   1030   1030  ...
#  16.0             1726        1726         1329     1267   1267   1267  ...
#  17.0              925         925          748      562    562    562  ...
#  18.0             2439        2439         1946     1536   1536   1536  ...
#  19.0              624         624          538      390    390    390  ...
#  20.0              871         871          736      480    480    480  ...
#  21.0             1239        1239         1058      838    838    838  ...
#  22.0              464         464          395      253    253    253  ...
#  23.0              494         494          424      289    289    289  ...
#  24.0             2687        2687         2215     2169   2169   2169  ...
#  25.0              709         709          614      403    403    403  ...
#  26.0              810         810          675      568    568    568  ...
#  27.0              666         666          578      490    490    490  ...
#  28.0              982         982          814      594    594    594  ...
# ...                ...         ...          ...      ...    ...    ...  ...
#  2578.0              1           1            0        1      1      1  ...
#  2579.0              1           1            0        1      1      1  ...
#  2594.0              1           1            1        1      1      1  ...
#  2610.0              1           1            1        1      1      1  ...
#  2689.0              1           1            1        1      1      1  ...
#  2692.0              1           1            1        0      0      0  ...
#  2741.0              1           1            0        1      1      1  ...
#  2762.0              2           2            2        2      2      2  ...
#  2794.0              1           1            1        0      0      0  ...
#  2928.0              1           1            1        1      1      1  ...
#  2992.0              1           1            1        1      1      1  ...
#  3080.0              1           1            1        1      1      1  ...
#  3102.0              1           1            0        1      1      1  ...
#  3239.0              1           1            0        1      1      1  ...
#  3308.0              1           1            1        1      1      1  ...
#  3521.0              1           1            1        0      0      0  ...
#  3522.0              1           1            1        1      1      1  ...
#  3542.0              2           2            0        1      1      1  ...
#  3598.0              1           1            0        1      1      1  ...
#  3690.0              2           2            2        0      0      0  ...
#  3882.0              1           1            1        0      0      0  ...
#  3923.0              1           1            1        0      0      0  ...
#  3966.0              1           1            0        1      1      1  ...
#  4015.0              8           8            8        8      8      8  ...
#  4161.0              1           1            1        1      1      1  ...
#  4521.0              1           1            1        0      0      0  ...
#  4772.0              1           1            1        1      1      1  ...
#  4981.0              1           1            1        0      0      0  ...
#  5005.0              1           1            0        0      0      0  ...
#  5027.0              1           1            0        0      0      0  ...
#
#           price_per_m2  floor  rooms  expenses  properati_url  description  \
# amb_aux1
# -1.0             32283   2383  15275      4216          44542        44542
#  0.0               140      1    159        12            199          199
#  1.0                40      1     39         0             43           43
#  2.0              1052    150   1011       280           1359         1359
#  3.0                68      0     64        13             88           88
#  4.0               834     22    430       194           1047         1047
#  5.0               320     12    203        41            372          372
#  6.0                73      0     32        11             78           78
#  7.0               428      8    233        38            502          502
#  8.0               497      8    392        98            597          597
#  9.0               394      4    268        41            486          486
#  10.0              638      8    333       108            731          731
#  11.0              557     34    252       146            631          631
#  12.0              968     22    508       238           1156         1156
#  13.0              379     13    147        65            443          443
#  14.0              630     21    335       152            727          727
#  15.0             1383     73    936       258           1639         1639
#  16.0             1343     30    845        96           1726         1726
#  17.0              789     69    407       121            925          925
#  18.0             2030    116   1224       490           2439         2439
#  19.0              495     17    305        89            624          624
#  20.0              664     22    406        98            871          871
#  21.0             1070    235    349       286           1239         1239
#  22.0              381     11    213        87            464          464
#  23.0              433     24    217       106            494          494
#  24.0             2020    749   1680      1029           2687         2687
#  25.0              640     42    330       120            709          709
#  26.0              638    129    442       190            810          810
#  27.0              576     37    359       138            666          666
#  28.0              807     45    440       235            982          982
# ...                ...    ...    ...       ...            ...          ...
#  2578.0              1      0      0         0              1            1
#  2579.0              1      0      0         0              1            1
#  2594.0              1      0      1         0              1            1
#  2610.0              0      0      0         0              1            1
#  2689.0              0      0      1         0              1            1
#  2692.0              1      0      0         0              1            1
#  2741.0              1      0      0         0              1            1
#  2762.0              2      0      0         2              2            2
#  2794.0              1      0      1         0              1            1
#  2928.0              1      0      1         0              1            1
#  2992.0              1      0      1         0              1            1
#  3080.0              1      0      1         0              1            1
#  3102.0              1      0      0         0              1            1
#  3239.0              1      0      1         0              1            1
#  3308.0              0      0      1         0              1            1
#  3521.0              1      0      0         0              1            1
#  3522.0              0      0      1         0              1            1
#  3542.0              1      0      0         1              2            2
#  3598.0              0      0      1         0              1            1
#  3690.0              2      0      0         0              2            2
#  3882.0              1      0      0         0              1            1
#  3923.0              1      0      0         0              1            1
#  3966.0              1      0      1         0              1            1
#  4015.0              0      0      8         0              8            8
#  4161.0              0      0      1         0              1            1
#  4521.0              1      0      0         0              1            1
#  4772.0              0      0      1         0              1            1
#  4981.0              1      0      0         0              1            1
#  5005.0              1      0      0         1              1            1
#  5027.0              1      0      0         1              1            1
#
#           title  image_thumbnail  district_name  city_name
# amb_aux1
# -1.0      44542            43015          44542      15792
#  0.0        199              199            199         25
#  1.0         43               43             43          5
#  2.0       1359             1300           1359        205
#  3.0         88               88             88         10
#  4.0       1047             1022           1047        217
#  5.0        372              368            372        130
#  6.0         78               78             78         36
#  7.0        502              497            502        227
#  8.0        597              592            597        134
#  9.0        486              480            486        185
#  10.0       731              724            731        255
#  11.0       631              615            631        190
#  12.0      1156             1141           1156        431
#  13.0       443              438            443        193
#  14.0       727              726            727        234
#  15.0      1639             1617           1639        607
#  16.0      1726             1720           1726        970
#  17.0       925              912            925        387
#  18.0      2439             2411           2439        927
#  19.0       624              618            624        235
#  20.0       871              853            871        358
#  21.0      1239             1213           1239        373
#  22.0       464              455            464        169
#  23.0       494              478            494        163
#  24.0      2687             2681           2687       1051
#  25.0       709              700            709        281
#  26.0       810              797            810        261
#  27.0       666              663            666        196
#  28.0       982              978            982        323
# ...         ...              ...            ...        ...
#  2578.0       1                1              1          1
#  2579.0       1                1              1          1
#  2594.0       1                1              1          1
#  2610.0       1                1              1          0
#  2689.0       1                1              1          0
#  2692.0       1                1              1          1
#  2741.0       1                1              1          1
#  2762.0       2                2              2          0
#  2794.0       1                1              1          0
#  2928.0       1                1              1          0
#  2992.0       1                1              1          1
#  3080.0       1                1              1          0
#  3102.0       1                1              1          1
#  3239.0       1                1              1          1
#  3308.0       1                1              1          0
#  3521.0       1                1              1          0
#  3522.0       1                1              1          0
#  3542.0       2                2              2          2
#  3598.0       1                1              1          1
#  3690.0       2                2              2          1
#  3882.0       1                1              1          0
#  3923.0       1                1              1          0
#  3966.0       1                1              1          1
#  4015.0       8                8              8          0
#  4161.0       1                1              1          0
#  4521.0       1                1              1          0
#  4772.0       1                1              1          0
#  4981.0       1                1              1          0
#  5005.0       1                1              1          1
#  5027.0       1                1              1          1
#
# [1590 rows x 27 columns]

# %%
dfprop['amb_aux1']=dfprop.loc[dfprop['amb_aux1'] !=-1].fillna(0)
dfprop['amb_aux1']=dfprop.loc[dfprop['amb_aux1'] !=-1].astype(np.int64)
dfprop['num_aux1']=dfprop.loc[dfprop['amb_aux1'] !=-11].apply(lambda x: dfprop['description'][(dfprop['amb_aux1']-2):dfprop['amb_aux1']], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-b025ed7d492d> in <module>
#       1 dfprop['amb_aux1']=dfprop.loc[dfprop['amb_aux1'] !=-1].fillna(0)
# ----> 2 dfprop['amb_aux1']=dfprop.loc[dfprop['amb_aux1'] !=-1].astype(np.int64)
#       3 dfprop['num_aux1']=dfprop.loc[dfprop['amb_aux1'] !=-11].apply(lambda x: dfprop['description'][(dfprop['amb_aux1']-2):dfprop['amb_aux1']], axis=1)
#
# /opt/conda/envs/geopandas/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5679             # else, only a single dtype is given
#    5680             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5681                                          **kwargs)
#    5682             return self._constructor(new_data).__finalize__(self)
#    5683
#
# /opt/conda/envs/geopandas/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# /opt/conda/envs/geopandas/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     393                                             copy=align_copy)
#     394
# --> 395             applied = getattr(b, f)(**kwargs)
#     396             result_blocks = _extend_blocks(applied, result_blocks)
#     397
#
# /opt/conda/envs/geopandas/lib/python3.7/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     532     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     533         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 534                             **kwargs)
#     535
#     536     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# /opt/conda/envs/geopandas/lib/python3.7/site-packages/pandas/core/internals/blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     631
#     632                     # _astype_nansafe works fine with 1-d only
# --> 633                     values = astype_nansafe(values.ravel(), dtype, copy=True)
#     634
#     635                 # TODO(extension)
#
# /opt/conda/envs/geopandas/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     674
#     675         if not np.isfinite(arr).all():
# --> 676             raise ValueError('Cannot convert non-finite values (NA or inf) to '
#     677                              'integer')
#     678
#
# ValueError: Cannot convert non-finite values (NA or inf) to integer

# %%
dfprop['property_type'].unique()
# Out:
# array(['PH', 'apartment', 'house'], dtype=object)

# %%
a=dfprop['description'].str.find('POSO')
ar=a[((a!=-1)&(~(pd.isna(a))))].index
dfprop.iloc[np.array(ar)].loc[:,'description']
# Out:
# 2511     ZONA:RESIDENCIAL-ASFALTO-OBRA SANITARIA:CLOACA...
# 4740     DEPARTAMENTOS DE 1 AMBIENTE DE 28 M² Y DE 2 AM...
# 4741     DEPARTAMENTOS DE 1 AMBIENTE DE 32 M² Y DE 2 AM...
# 4743     DEPARTAMENTOS DE 1 AMBIENTE DE 32 M² Y DE 2 AM...
# 13978    VENTA - DEPARTAMENTO - ARGENTINA, BUENOS AIRES...
# 25589    CORREDOR RESPONSABLE: MAURO MARVISI - CMCPSI 5...
# 28804    CORREDOR RESPONSABLE: MAXIMILIANO VAZQUEZ - C....
# 31182    CHALET PH EN VENTA, CUENTA CON: LIVING COMEDOR...
# 37183    CORREDOR RESPONSABLE: RAMIRO CAPPELLONI - C.M....
# 43650    CORREDOR RESPONSABLE: MATIAS CASTELLI - CUCICB...
# 52908    DEPARTAMENTO 1 DORMITORIO EN ABASTO, ROSARIO.(...
# 75790    AMPLIO DEPARTAMENTO DE 4 AMBIENTES CON PATIO I...
# 77977    VENTA DE DEPARTAMENTO 2 AMBIENTES EN TIGRETIGR...
# 84773    VENTA DE CASA 4 AMBIENTES EN MARIA EUGENIA RES...
# 95199    HERMOSA PROPIEDAD UBICADA EN ZONA RESIDENCIAL ...
# 99359    BEHM SERVICIOS INMOBILIARIOS PRESENTA CASA EN ...
# Name: description, dtype: object

# %%
def new_dummy_from_included_in_column(dfprop_aux,column,word):
    #dfprop_aux=dfprop
    #word='POZO'
    
    #Creamos la expresion regular ..."que el texto empiece con"... word 
    re_word="("+word+"+\w+)"
    
    #Creamos la expresion regular
    re_search=dfprop[column].str.extract(re_word,expand=False)
    
    #re_search[((re_search!=-1)&(~(pd.isna(re_search))))].index
    #Creamos la columna dummy y seteamos todos los rows en 0
    dfprop_aux.loc[:,"dm_"+word]=0
    
    #Extraemos la lista de de indices donde la expresion se cumple
    prop_re_list =np.array(re_search[((re_search!=-1)&(~(pd.isna(re_search))))].index)
    
    #Actualizamos el valor de la columna Dummy a 1 en los casos dentro del indice enviado
    dfprop_aux.loc[dfprop_aux.index.isin(prop_re_list),"dm_"+word]=1
    
    return dfprop_aux

def new_dummy_from_included(dfprop_aux_,word_):
    dfprop_aux_=new_dummy_from_included_in_column(dfprop_aux_,'description',word_)
    dfprop_aux_=new_dummy_from_included_in_column(dfprop_aux_,'title',word_)
    print_dummy_count_rows(dfprop_aux_,'dm_'+word_)
    return dfprop_aux_

def print_dummy_count_rows(dfprop_aux_p,word_p):
    print('Cantidad de rows con '+word_p+": ",dfprop_aux_p.loc[dfprop_aux_p[word_p]==1,'dm_PARRILLA'].count())

# %%
dfprop=new_dummy_from_included(dfprop,'CONDOMINIO')
dfprop=new_dummy_from_included(dfprop,'CONSTRUCCION')
dfprop=new_dummy_from_included(dfprop,'QUINCHO')
dfprop=new_dummy_from_included(dfprop,'BARRIO CERRADO')
dfprop=new_dummy_from_included(dfprop,'BAULERA')
dfprop=new_dummy_from_included(dfprop,'VIGILANCIA')
dfprop=new_dummy_from_included(dfprop,'OBRA')
dfprop=new_dummy_from_included(dfprop,'PARRILLA')
dfprop=new_dummy_from_included(dfprop,'CERRADO')
dfprop=new_dummy_from_included(dfprop,'MONOAMBIENTE')
dfprop=new_dummy_from_included(dfprop,'ESCUELA')
dfprop=new_dummy_from_included(dfprop,'ESCUELA')
dfprop=new_dummy_from_included(dfprop,'EXPENSA')
# Out:
# Cantidad de rows con dm_CONDOMINIO:  112
# Cantidad de rows con dm_CONSTRUCCION:  1
# Cantidad de rows con dm_QUINCHO:  1
# Cantidad de rows con dm_BARRIO CERRADO:  0
# Cantidad de rows con dm_BAULERA:  14
# Cantidad de rows con dm_VIGILANCIA:  0
# Cantidad de rows con dm_OBRA:  0
# Cantidad de rows con dm_PARRILLA:  14
# Cantidad de rows con dm_CERRADO:  15
# Cantidad de rows con dm_MONOAMBIENTE:  197
# Cantidad de rows con dm_ESCUELA:  1
# Cantidad de rows con dm_ESCUELA:  1
# Cantidad de rows con dm_EXPENSA:  387

# %%
#Ajustamos la dummy de expensas con la existencia de una valor en la columna "expenses"
dfprop.loc[(dfprop['dm_EXPENSA']==0)&(~pd.isna(dfprop['expenses'])),'dm_EXPENSA']=1

print_dummy_count_rows(dfprop,'dm_EXPENSA')
# Out:
# Cantidad de rows con dm_EXPENSA:  13406
